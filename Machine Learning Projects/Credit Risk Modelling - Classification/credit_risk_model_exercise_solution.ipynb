# %% [markdown]
# <h2 align='center' style='color:blue'>Codebasics ML Course: Credit Risk Modeling Exercise Solution</h2>

# %%
# !which python
# Out:
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/bin/python

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

pd.set_option('display.float_format', lambda x: '{:.2f}'.format(x))
np.set_printoptions(suppress=True)

# %% [markdown]
# ### Load Data

# %%
df_customers = pd.read_csv("dataset/customers.csv")
df_loans = pd.read_csv("dataset/loans.csv")
df_bureau = pd.read_csv("dataset/bureau_data.csv")

# %%
df_customers.shape, df_loans.shape, df_bureau.shape
# Out:
# ((50000, 12), (50000, 15), (50000, 8))

# %%
df_customers.head(3)
# Out:
#   cust_id  age gender marital_status employment_status   income  \
# 0  C00001   44      M        Married     Self-Employed  2586000
# 1  C00002   38      M        Married          Salaried  1206000
# 2  C00003   46      F        Married     Self-Employed  2878000
#
#    number_of_dependants residence_type  years_at_current_address     city  \
# 0                     3          Owned                        27    Delhi
# 1                     3          Owned                         4  Chennai
# 2                     3          Owned                        24  Kolkata
#
#          state  zipcode
# 0        Delhi   110001
# 1   Tamil Nadu   600001
# 2  West Bengal   700001

# %%
df_loans.head(3)
# Out:
#   loan_id cust_id loan_purpose  loan_type  sanction_amount  loan_amount  \
# 0  L00001  C00001         Auto    Secured          3004000      2467000
# 1  L00002  C00002         Home    Secured          4161000      3883000
# 2  L00003  C00003     Personal  Unsecured          2401000      2170000
#
#    processing_fee     gst  net_disbursement  loan_tenure_months  \
# 0        49340.00  444060           1973600                  33
# 1        77660.00  698940           3106400                  30
# 2        43400.00  390600           1736000                  21
#
#    principal_outstanding  bank_balance_at_application disbursal_date  \
# 0                1630408                       873386     2019-07-24
# 1                 709309                       464100     2019-07-24
# 2                1562399                      1476042     2019-07-24
#
#   installment_start_dt  default
# 0           2019-08-10    False
# 1           2019-08-15    False
# 2           2019-08-21    False

# %%
df_bureau.head(3)
# Out:
#   cust_id  number_of_open_accounts  number_of_closed_accounts  \
# 0  C00001                        1                          1
# 1  C00002                        3                          1
# 2  C00003                        2                          1
#
#    total_loan_months  delinquent_months  total_dpd  enquiry_count  \
# 0                 42                  0          0              3
# 1                 96                 12         60              5
# 2                 82                 24        147              6
#
#    credit_utilization_ratio
# 0                         7
# 1                         4
# 2                        58

# %%
df = pd.merge(df_customers, df_loans, on='cust_id')
df.head(3)
# Out:
#   cust_id  age gender marital_status employment_status   income  \
# 0  C00001   44      M        Married     Self-Employed  2586000
# 1  C00002   38      M        Married          Salaried  1206000
# 2  C00003   46      F        Married     Self-Employed  2878000
#
#    number_of_dependants residence_type  years_at_current_address     city  \
# 0                     3          Owned                        27    Delhi
# 1                     3          Owned                         4  Chennai
# 2                     3          Owned                        24  Kolkata
#
#    ... loan_amount  processing_fee     gst net_disbursement  \
# 0  ...     2467000        49340.00  444060          1973600
# 1  ...     3883000        77660.00  698940          3106400
# 2  ...     2170000        43400.00  390600          1736000
#
#   loan_tenure_months  principal_outstanding  bank_balance_at_application  \
# 0                 33                1630408                       873386
# 1                 30                 709309                       464100
# 2                 21                1562399                      1476042
#
#    disbursal_date  installment_start_dt  default
# 0      2019-07-24            2019-08-10    False
# 1      2019-07-24            2019-08-15    False
# 2      2019-07-24            2019-08-21    False
#
# [3 rows x 26 columns]

# %%
df = pd.merge(df, df_bureau, on='cust_id')
df.head(3)
# Out:
#   cust_id  age gender marital_status employment_status   income  \
# 0  C00001   44      M        Married     Self-Employed  2586000
# 1  C00002   38      M        Married          Salaried  1206000
# 2  C00003   46      F        Married     Self-Employed  2878000
#
#    number_of_dependants residence_type  years_at_current_address     city  \
# 0                     3          Owned                        27    Delhi
# 1                     3          Owned                         4  Chennai
# 2                     3          Owned                        24  Kolkata
#
#    ... disbursal_date  installment_start_dt default number_of_open_accounts  \
# 0  ...     2019-07-24            2019-08-10   False                       1
# 1  ...     2019-07-24            2019-08-15   False                       3
# 2  ...     2019-07-24            2019-08-21   False                       2
#
#   number_of_closed_accounts  total_loan_months  delinquent_months  total_dpd  \
# 0                         1                 42                  0          0
# 1                         1                 96                 12         60
# 2                         1                 82                 24        147
#
#    enquiry_count  credit_utilization_ratio
# 0              3                         7
# 1              5                         4
# 2              6                        58
#
# [3 rows x 33 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 33 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   cust_id                      50000 non-null  object
#  1   age                          50000 non-null  int64
#  2   gender                       50000 non-null  object
#  3   marital_status               50000 non-null  object
#  4   employment_status            50000 non-null  object
#  5   income                       50000 non-null  int64
#  6   number_of_dependants         50000 non-null  int64
#  7   residence_type               49938 non-null  object
#  8   years_at_current_address     50000 non-null  int64
#  9   city                         50000 non-null  object
#  10  state                        50000 non-null  object
#  11  zipcode                      50000 non-null  int64
#  12  loan_id                      50000 non-null  object
#  13  loan_purpose                 50000 non-null  object
#  14  loan_type                    50000 non-null  object
#  15  sanction_amount              50000 non-null  int64
#  16  loan_amount                  50000 non-null  int64
#  17  processing_fee               50000 non-null  float64
#  18  gst                          50000 non-null  int64
#  19  net_disbursement             50000 non-null  int64
#  20  loan_tenure_months           50000 non-null  int64
#  21  principal_outstanding        50000 non-null  int64
#  22  bank_balance_at_application  50000 non-null  int64
#  23  disbursal_date               50000 non-null  object
#  24  installment_start_dt         50000 non-null  object
#  25  default                      50000 non-null  bool
#  26  number_of_open_accounts      50000 non-null  int64
#  27  number_of_closed_accounts    50000 non-null  int64
#  28  total_loan_months            50000 non-null  int64
#  29  delinquent_months            50000 non-null  int64
#  30  total_dpd                    50000 non-null  int64
#  31  enquiry_count                50000 non-null  int64
#  32  credit_utilization_ratio     50000 non-null  int64
# dtypes: bool(1), float64(1), int64(19), object(12)
# memory usage: 12.3+ MB

# %%
df['default'] = df['default'].astype(int)
df.default.value_counts()
# Out:
# default
# 0    45703
# 1     4297
# Name: count, dtype: int64

# %% [markdown]
# default is a target variable and we can see some class imbalance here. We will address it later on.

# %% [markdown]
# ### Train Test split

# %% [markdown]
# We perform train test split before doing EDA to prevent data leakage. We don't want test set (which is part of the entire dataset) to influence EDA or any decisions on feature engineering.

# %%
X = df.drop("default", axis="columns")
y = df['default']

X_train,X_test,y_train,y_test=train_test_split(X,y,stratify=y,test_size=0.25,random_state=42)

df_train = pd.concat([X_train, y_train], axis="columns")
df_test = pd.concat([X_test, y_test], axis="columns")

df_train.head(2)
# Out:
#       cust_id  age gender marital_status employment_status    income  \
# 12746  C12747   59      M        Married     Self-Employed  11327000
# 32495  C32496   44      F         Single          Salaried    715000
#
#        number_of_dependants residence_type  years_at_current_address  \
# 12746                     3          Owned                        30
# 32495                     0          Owned                        27
#
#             city  ... disbursal_date  installment_start_dt  \
# 12746  Hyderabad  ...     2020-10-31            2020-11-11
# 32495     Mumbai  ...     2022-10-22            2022-10-27
#
#       number_of_open_accounts number_of_closed_accounts total_loan_months  \
# 12746                       4                         2               152
# 32495                       3                         1               160
#
#        delinquent_months  total_dpd  enquiry_count  credit_utilization_ratio  \
# 12746                 20        118              4                        36
# 32495                 10         62              5                         5
#
#        default
# 12746        0
# 32495        0
#
# [2 rows x 33 columns]

# %% [markdown]
# <h3 align="center" style="color:blue">Data Cleaning</h3>

# %% [markdown]
# ### Handle Missing & Duplicate Values

# %%
df_train.shape
# Out:
# (37500, 33)

# %%
df_train.isna().sum()
# Out:
# cust_id                         0
# age                             0
# gender                          0
# marital_status                  0
# employment_status               0
# income                          0
# number_of_dependants            0
# residence_type                 47
# years_at_current_address        0
# city                            0
# state                           0
# zipcode                         0
# loan_id                         0
# loan_purpose                    0
# loan_type                       0
# sanction_amount                 0
# loan_amount                     0
# processing_fee                  0
# gst                             0
# net_disbursement                0
# loan_tenure_months              0
# principal_outstanding           0
# bank_balance_at_application     0
# disbursal_date                  0
# installment_start_dt            0
# number_of_open_accounts         0
# number_of_closed_accounts       0
# total_loan_months               0
# delinquent_months               0
# total_dpd                       0
# enquiry_count                   0
# credit_utilization_ratio        0
# default                         0
# dtype: int64

# %%
df_train.residence_type.unique()
# Out:
# array(['Owned', 'Mortgage', 'Rented', nan], dtype=object)

# %%
mode_residence = df_train.residence_type.mode()[0]
mode_residence
# Out:
# 'Owned'

# %%
df_train.residence_type.fillna(mode_residence, inplace=True)
df_test.residence_type.fillna(mode_residence, inplace=True)

df_train.residence_type.unique(), df_test.residence_type.unique()
# Out:
# /var/folders/mp/7dl9lrks6q76s90zsdq13b4m0000gq/T/ipykernel_44853/2805913581.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_train.residence_type.fillna(mode_residence, inplace=True)
# /var/folders/mp/7dl9lrks6q76s90zsdq13b4m0000gq/T/ipykernel_44853/2805913581.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_test.residence_type.fillna(mode_residence, inplace=True)
# (array(['Owned', 'Mortgage', 'Rented'], dtype=object),
#  array(['Owned', 'Mortgage', 'Rented'], dtype=object))

# %%
df_train.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_train.describe()
# Out:
#            age      income  number_of_dependants  years_at_current_address  \
# count 37500.00    37500.00              37500.00                  37500.00
# mean     39.54  2633326.16                  1.94                     16.00
# std       9.86  2623780.52                  1.54                      8.92
# min      18.00        0.00                  0.00                      1.00
# 25%      33.00   802000.00                  0.00                      8.00
# 50%      39.00  1885000.00                  2.00                     16.00
# 75%      46.00  3326250.00                  3.00                     24.00
# max      70.00 11999000.00                  5.00                     31.00
#
#         zipcode  sanction_amount  loan_amount  processing_fee        gst  \
# count  37500.00         37500.00     37500.00        37500.00   37500.00
# mean  418866.25       4699691.57   3996067.73        80290.68  719292.19
# std   169035.02       6257832.98   5371862.29       113128.14  966935.21
# min   110001.00             0.00         0.00            0.00       0.00
# 25%   302001.00       1142000.00    961000.00        19220.00  172980.00
# 50%   400001.00       2644000.00   2230000.00        44600.00  401400.00
# 75%   560001.00       5178000.00   4619000.00        92420.00  831420.00
# max   700001.00      52175000.00  47819000.00      5293543.52 8607420.00
#
#        net_disbursement  ...  principal_outstanding  \
# count          37500.00  ...               37500.00
# mean         3196854.19  ...             1333819.51
# std          4297489.83  ...             1213674.44
# min                0.00  ...                  -1.00
# 25%           768800.00  ...              422197.50
# 50%          1784000.00  ...              997427.50
# 75%          3695200.00  ...             1784879.00
# max         38255200.00  ...             5000000.00
#
#        bank_balance_at_application  number_of_open_accounts  \
# count                     37500.00                 37500.00
# mean                     986298.87                     2.50
# std                     1043145.01                     1.12
# min                           0.00                     1.00
# 25%                      287040.25                     1.00
# 50%                      665014.50                     3.00
# 75%                     1234062.75                     4.00
# max                     7846643.00                     4.00
#
#        number_of_closed_accounts  total_loan_months  delinquent_months  \
# count                   37500.00           37500.00           37500.00
# mean                        1.00              76.11               4.84
# std                         0.81              43.77               5.84
# min                         0.00               1.00               0.00
# 25%                         0.00              42.00               0.00
# 50%                         1.00              71.00               3.00
# 75%                         2.00             107.00               8.00
# max                         2.00             223.00              24.00
#
#        total_dpd  enquiry_count  credit_utilization_ratio  default
# count   37500.00       37500.00                  37500.00 37500.00
# mean       26.67           5.01                     43.42     0.09
# std        32.78           2.03                     29.39     0.28
# min         0.00           1.00                      0.00     0.00
# 25%         0.00           4.00                     18.00     0.00
# 50%        13.00           5.00                     39.00     0.00
# 75%        46.00           6.00                     67.00     0.00
# max       171.00           9.00                     99.00     1.00
#
# [8 rows x 21 columns]

# %%
df_train.columns
# Out:
# Index(['cust_id', 'age', 'gender', 'marital_status', 'employment_status',
#        'income', 'number_of_dependants', 'residence_type',
#        'years_at_current_address', 'city', 'state', 'zipcode', 'loan_id',
#        'loan_purpose', 'loan_type', 'sanction_amount', 'loan_amount',
#        'processing_fee', 'gst', 'net_disbursement', 'loan_tenure_months',
#        'principal_outstanding', 'bank_balance_at_application',
#        'disbursal_date', 'installment_start_dt', 'number_of_open_accounts',
#        'number_of_closed_accounts', 'total_loan_months', 'delinquent_months',
#        'total_dpd', 'enquiry_count', 'credit_utilization_ratio', 'default'],
#       dtype='object')

# %%
columns_continuous = ['age', 'income', 'number_of_dependants', 'years_at_current_address',
                      'sanction_amount', 'loan_amount', 'processing_fee', 'gst', 'net_disbursement',
                      'loan_tenure_months','principal_outstanding', 'bank_balance_at_application',
                      'number_of_open_accounts','number_of_closed_accounts', 'total_loan_months', 'delinquent_months',
                       'total_dpd', 'enquiry_count', 'credit_utilization_ratio']

columns_categorical = ['gender', 'marital_status', 'employment_status', 'residence_type', 'city',
                       'state', 'zipcode', 'loan_purpose', 'loan_type', 'default']

# %% [markdown]
# ### Box plot to visualize outliers

# %%
num_plots = len(columns_continuous)
num_cols = 4  # Number of plots per row
num_rows = (num_plots + num_cols - 1) // num_cols  # Calculate the number of rows needed

fig, axes = plt.subplots(num_rows, num_cols, figsize=(5 * num_cols, 5 * num_rows))  # Adjust the figure size as needed
axes = axes.flatten()  # Flatten the axes array for easier indexing

for i, col in enumerate(columns_continuous):
    sns.boxplot(x=df_train[col], ax=axes[i])
    axes[i].set_title(col)  # Set the title to the name of the variable

# If there are any empty plots (if the number of plots isn't a perfect multiple of num_cols), hide the axes
for j in range(i + 1, num_rows * num_cols):
    axes[j].axis('off')

plt.tight_layout()
plt.show()

# %%
num_plots = len(columns_continuous)
num_cols = 4  # Number of plots per row
num_rows = (num_plots + num_cols - 1) // num_cols  # Calculate the number of rows needed

fig, axes = plt.subplots(num_rows, num_cols, figsize=(5 * num_cols, 5 * num_rows))  # Adjust the figure size as needed
axes = axes.flatten()  # Flatten the axes array for easier indexing

for i, col in enumerate(columns_continuous):
    sns.histplot(df_train[col], ax=axes[i])
    axes[i].set_title(col)  # Set the title to the name of the variable

# If there are any empty plots (if the number of plots isn't a perfect multiple of num_cols), hide the axes
for j in range(i + 1, num_rows * num_cols):
    axes[j].axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Outlier Removal: Processing Fee

# %%
df_train.processing_fee.describe()
# Out:
# count     37500.00
# mean      80290.68
# std      113128.14
# min           0.00
# 25%       19220.00
# 50%       44600.00
# 75%       92420.00
# max     5293543.52
# Name: processing_fee, dtype: float64

# %%
#Business mentioned that processing fee should not be more than 3% of loan amount
df_train[(df_train.processing_fee/df_train.loan_amount)>0.03][["loan_amount","processing_fee"]]
# Out:
#        loan_amount  processing_fee
# 23981      2234000      2669791.02
# 28174       966000      1214492.67
# 47089      1738000      1858964.77
# 29305      2616000      3036378.01
# 9898       3626000      5293543.52

# %%
df_train_1 = df_train[df_train.processing_fee/df_train.loan_amount<0.03].copy()
df_train_1.shape
# Out:
# (37488, 33)

# %%
df_test.residence_type.isna().sum()
# Out:
# np.int64(0)

# %%
# Apply same step on test set
df_test = df_test[df_test.processing_fee/df_test.loan_amount<0.03].copy()
df_test.shape
# Out:
# (12497, 33)

# %%
# Use other business rules for data validation
# Rule 1: GST should not be more than 20%

df_train_1[(df_train_1.gst/df_train_1.loan_amount)>0.2].shape
# Out:
# (0, 33)

# %%
# Rule 2: Net disbursement should not be higher than loan_amount
df_train_1[df_train_1.net_disbursement>df_train_1.loan_amount].shape
# Out:
# (0, 33)

# %% [markdown]
# No rows found that breaks rule 1 and rule 2

# %% [markdown]
# ### Analyze Categorical Columns

# %%
columns_categorical
# Out:
# ['gender',
#  'marital_status',
#  'employment_status',
#  'residence_type',
#  'city',
#  'state',
#  'zipcode',
#  'loan_purpose',
#  'loan_type',
#  'default']

# %%
for col in columns_categorical:
    print(col, "-->", df_train_1[col].unique())
# Out:
# gender --> ['M' 'F']
# marital_status --> ['Married' 'Single']
# employment_status --> ['Self-Employed' 'Salaried']
# residence_type --> ['Owned' 'Mortgage' 'Rented']
# city --> ['Hyderabad' 'Mumbai' 'Chennai' 'Bangalore' 'Pune' 'Kolkata' 'Ahmedabad'
#  'Delhi' 'Lucknow' 'Jaipur']
# state --> ['Telangana' 'Maharashtra' 'Tamil Nadu' 'Karnataka' 'West Bengal'
#  'Gujarat' 'Delhi' 'Uttar Pradesh' 'Rajasthan']
# zipcode --> [500001 400001 600001 560001 411001 700001 380001 110001 226001 302001]
# loan_purpose --> ['Home' 'Education' 'Personal' 'Auto' 'Personaal']
# loan_type --> ['Secured' 'Unsecured']
# default --> [0 1]

# %% [markdown]
# ### Fix Errors in Loan Purpose Column

# %%
df_train_1['loan_purpose'] = df_train_1['loan_purpose'].replace('Personaal', 'Personal')
df_train_1['loan_purpose'].unique()
# Out:
# array(['Home', 'Education', 'Personal', 'Auto'], dtype=object)

# %%
df_test['loan_purpose'] = df_test['loan_purpose'].replace('Personaal', 'Personal')
df_test['loan_purpose'].unique()
# Out:
# array(['Home', 'Education', 'Auto', 'Personal'], dtype=object)

# %% [markdown]
# <h3 style="color:blue" align="center">Exploratory Data Analysis</h3>

# %%
columns_continuous
# Out:
# ['age',
#  'income',
#  'number_of_dependants',
#  'years_at_current_address',
#  'sanction_amount',
#  'loan_amount',
#  'processing_fee',
#  'gst',
#  'net_disbursement',
#  'loan_tenure_months',
#  'principal_outstanding',
#  'bank_balance_at_application',
#  'number_of_open_accounts',
#  'number_of_closed_accounts',
#  'total_loan_months',
#  'delinquent_months',
#  'total_dpd',
#  'enquiry_count',
#  'credit_utilization_ratio']

# %% [markdown]
# ### Age Column

# %%
df_train_1.groupby("default")['age'].describe()
# Out:
#            count  mean  std   min   25%   50%   75%   max
# default
# 0       34265.00 39.77 9.88 18.00 33.00 40.00 46.00 70.00
# 1        3223.00 37.12 9.29 18.00 31.00 37.00 44.00 70.00

# %% [markdown]
# **Insights**
#
# 1. Average age in the default group is little less (37.12) than the average (39.7) of the group that did not default
# 1. Variability (standard deviation) is mostly similar in both the groups
# 1. Both the groups have similar min and max ages

# %%
plt.figure(figsize=(8, 4))
sns.kdeplot(df_train_1['age'][df_train_1['default'] == 0], fill=True, label='default=0')
sns.kdeplot(df_train_1['age'][df_train_1['default'] == 1], fill=True, label='default=1')
plt.title(f"Age KDE Plot with Hue by default")
plt.legend()
plt.show()

# %% [markdown]
# **Insights**
#
# 1. Orange (defaulted) group is slightly shifted to left indicating that younger folks are more likely to default on their loans

# %% [markdown]
# ### KDE for all the Columns

# %%
plt.figure(figsize=(24, 20))  # Width, height in inches

for i, col in enumerate(columns_continuous):
    plt.subplot(6, 4, i+1)  # 1 row, 4 columns, ith subplot
    sns.kdeplot(df_train_1[col][df_train_1['default']==0], fill=True, label='default=0')
    sns.kdeplot(df_train_1[col][df_train_1['default']==1], fill=True, label='default=1')
    plt.title(col)
    plt.xlabel('')

plt.tight_layout()
plt.show()

# %% [markdown]
# **Insights**
#
# 1. In columns: loan_tenure_months, delinquent_months, total_dpd, credit_utilization, higher values indicate high likelyhood of becoming a default. Hence these 4 looks like strong predictors
# 1. In remaining columns the distributions do not give any obvious insights
# 1. Why loan_amount and income did not give any signs of being strong predictors? May be when we combine these two and get loan to income ratio (LTI), that may have influence on the target variable. We will explore more later

# %% [markdown]
# <h3 style="color:blue" align="center">Feature Engineering, Feature Selection</h3>

# %% [markdown]
# #### Generate Loan to Income (LTI) Ratio

# %%
df_train_1[["loan_amount", "income"]].head(3)
# Out:
#        loan_amount    income
# 12746     23442000  11327000
# 32495      1149000    715000
# 43675     11296000   3195000

# %%
df_train_1['loan_to_income'] = round(df_train_1['loan_amount'] / df_train_1['income'],2)
df_train_1['loan_to_income'].describe()
# Out:
# count   37488.00
# mean        1.56
# std         0.97
# min         0.30
# 25%         0.77
# 50%         1.16
# 75%         2.46
# max         4.57
# Name: loan_to_income, dtype: float64

# %%
df_test['loan_to_income'] = round(df_test['loan_amount'] / df_test['income'],2)

# %%
plt.figure(figsize=(8, 4))
sns.kdeplot(df_train_1['loan_to_income'][df_train_1['default'] == 0], fill=True, label='default=0')
sns.kdeplot(df_train_1['loan_to_income'][df_train_1['default'] == 1], fill=True, label='default=1')
plt.title(f"Loan to Income Ratio (LTI) KDE Plot with Hue by default")
plt.legend()
plt.show()

# %% [markdown]
# **Insights**
# 1. Blue graph has majority of its values on lower side of LTI
# 2. Orange graph has many values when LTI is higher indicating that higher LTI means high risk loan

# %% [markdown]
# #### Generate Delinquency Ratio

# %%
df_train_1['delinquency_ratio'] = (df_train_1['delinquent_months']*100 / df_train_1['total_loan_months']).round(1)
df_test['delinquency_ratio'] = (df_test['delinquent_months']*100 / df_test['total_loan_months']).round(1)

# %%
plt.figure(figsize=(8, 4))
sns.kdeplot(df_train_1['delinquency_ratio'][df_train_1['default'] == 0], fill=True, label='default=0')
sns.kdeplot(df_train_1['delinquency_ratio'][df_train_1['default'] == 1], fill=True, label='default=1')
plt.title(f"Delinquency Ratio KDE Plot with Hue by default")
plt.legend()
plt.show()

# %% [markdown]
# **Insights**
# 1. Blue graph has majority of its values on lower side of LTI
# 2. Orange graph has many values when delinquency ratio is higher indicating some correlation on default

# %% [markdown]
# #### Generate Avg DPD Per Delinquency

# %%
df_train_1['avg_dpd_per_delinquency'] = np.where(
    df_train_1['delinquent_months'] != 0,
    (df_train_1['total_dpd'] / df_train_1['delinquent_months']).round(1),
    0
)

df_test['avg_dpd_per_delinquency'] = np.where(
    df_test['delinquent_months'] != 0,
    (df_test['total_dpd'] / df_test['delinquent_months']).round(1),
    0
)

# %%
plt.figure(figsize=(8, 4))
sns.kdeplot(df_train_1['avg_dpd_per_delinquency'][df_train_1['default'] == 0], fill=True, label='default=0')
sns.kdeplot(df_train_1['avg_dpd_per_delinquency'][df_train_1['default'] == 1], fill=True, label='default=1')
plt.title(f"Avg DPD Per Delinquency Ratio KDE Plot with Hue by default")
plt.legend()
plt.show()

# %% [markdown]
# **Insights**
#
# 1. Graph clearly shows more occurances of default cases when avg_dpd_per_delinquency is high. This means this column is a strong predictor

# %% [markdown]
# #### Generate Credit Utilization Per LTI

# %%
df_train_1['credit_utilization_per_income'] = np.where(
    df_train_1['loan_to_income'] != 0,
    (df_train_1['credit_utilization_ratio'] / df_train_1['loan_to_income']).round(1),
    0
)

df_test['credit_utilization_per_income'] = np.where(
    df_test['loan_to_income'] != 0,
    (df_test['credit_utilization_ratio'] / df_test['loan_to_income']).round(1),
    0
)

# %%
plt.figure(figsize=(8, 4))
sns.kdeplot(df_train_1['credit_utilization_per_income'][df_train_1['default'] == 0], fill=True, label='default=0')
sns.kdeplot(df_train_1['credit_utilization_per_income'][df_train_1['default'] == 1], fill=True, label='default=1')
plt.title(f"Credit Utilization Per Income Ratio KDE Plot with Hue by default")
plt.legend()
plt.show()

# %% [markdown]
# Graph clearly shows more occurrences of default cases when the Credit Utilization Per Income Ratio is high. This indicates that this column is a strong predictor of default risk.

# %% [markdown]
# ### Remove columns that are just unique ids and don't have influence on target

# %%
df_train_1.columns
# Out:
# Index(['cust_id', 'age', 'gender', 'marital_status', 'employment_status',
#        'income', 'number_of_dependants', 'residence_type',
#        'years_at_current_address', 'city', 'state', 'zipcode', 'loan_id',
#        'loan_purpose', 'loan_type', 'sanction_amount', 'loan_amount',
#        'processing_fee', 'gst', 'net_disbursement', 'loan_tenure_months',
#        'principal_outstanding', 'bank_balance_at_application',
#        'disbursal_date', 'installment_start_dt', 'number_of_open_accounts',
#        'number_of_closed_accounts', 'total_loan_months', 'delinquent_months',
#        'total_dpd', 'enquiry_count', 'credit_utilization_ratio', 'default',
#        'loan_to_income', 'delinquency_ratio', 'avg_dpd_per_delinquency',
#        'credit_utilization_per_income'],
#       dtype='object')

# %%
df_train_2 = df_train_1.drop(['cust_id', 'loan_id'],axis="columns")
df_test = df_test.drop(['cust_id', 'loan_id'],axis="columns")

# %% [markdown]
# ### Remove columns that business contact person asked us to remove

# %%
df_train_3 = df_train_2.drop(['disbursal_date', 'installment_start_dt', 'loan_amount', 'income',
                              'total_loan_months', 'delinquent_months', 'total_dpd'], axis="columns")
df_test = df_test.drop(['disbursal_date', 'installment_start_dt', 'loan_amount', 'income',
                              'total_loan_months', 'delinquent_months', 'total_dpd'], axis="columns")
df_train_3.columns
# Out:
# Index(['age', 'gender', 'marital_status', 'employment_status',
#        'number_of_dependants', 'residence_type', 'years_at_current_address',
#        'city', 'state', 'zipcode', 'loan_purpose', 'loan_type',
#        'sanction_amount', 'processing_fee', 'gst', 'net_disbursement',
#        'loan_tenure_months', 'principal_outstanding',
#        'bank_balance_at_application', 'number_of_open_accounts',
#        'number_of_closed_accounts', 'enquiry_count',
#        'credit_utilization_ratio', 'default', 'loan_to_income',
#        'delinquency_ratio', 'avg_dpd_per_delinquency',
#        'credit_utilization_per_income'],
#       dtype='object')

# %%
df_train_3.select_dtypes(['int64', 'float64']).columns
# Out:
# Index(['age', 'number_of_dependants', 'years_at_current_address', 'zipcode',
#        'sanction_amount', 'processing_fee', 'gst', 'net_disbursement',
#        'loan_tenure_months', 'principal_outstanding',
#        'bank_balance_at_application', 'number_of_open_accounts',
#        'number_of_closed_accounts', 'enquiry_count',
#        'credit_utilization_ratio', 'default', 'loan_to_income',
#        'delinquency_ratio', 'avg_dpd_per_delinquency',
#        'credit_utilization_per_income'],
#       dtype='object')

# %% [markdown]
# ### VIF to measure multicolinearity

# %%
X_train = df_train_3.drop('default', axis='columns')
y_train = df_train_3['default']

from sklearn.preprocessing import MinMaxScaler

cols_to_scale = X_train.select_dtypes(['int64', 'float64']).columns

scaler = MinMaxScaler()

X_train[cols_to_scale] = scaler.fit_transform(X_train[cols_to_scale])
X_train.describe()
# Out:
#            age  number_of_dependants  years_at_current_address  zipcode  \
# count 37488.00              37488.00                  37488.00 37488.00
# mean      0.41                  0.39                      0.50     0.52
# std       0.19                  0.31                      0.30     0.29
# min       0.00                  0.00                      0.00     0.00
# 25%       0.29                  0.00                      0.23     0.33
# 50%       0.40                  0.40                      0.50     0.49
# 75%       0.54                  0.60                      0.77     0.76
# max       1.00                  1.00                      1.00     1.00
#
#        sanction_amount  processing_fee      gst  net_disbursement  \
# count         37488.00        37488.00 37488.00          37488.00
# mean              0.09            0.08     0.08              0.08
# std               0.12            0.11     0.11              0.11
# min               0.00            0.00     0.00              0.00
# 25%               0.02            0.02     0.02              0.02
# 50%               0.05            0.05     0.05              0.05
# 75%               0.10            0.10     0.10              0.10
# max               1.00            1.00     1.00              1.00
#
#        loan_tenure_months  principal_outstanding  bank_balance_at_application  \
# count            37488.00               37488.00                     37488.00
# mean                 0.38                   0.26                         0.12
# std                  0.23                   0.24                         0.13
# min                  0.00                   0.00                         0.00
# 25%                  0.19                   0.08                         0.03
# 50%                  0.34                   0.19                         0.08
# 75%                  0.55                   0.35                         0.16
# max                  1.00                   1.00                         1.00
#
#        number_of_open_accounts  number_of_closed_accounts  enquiry_count  \
# count                 37488.00                   37488.00       37488.00
# mean                      0.50                       0.50           0.50
# std                       0.37                       0.41           0.25
# min                       0.00                       0.00           0.00
# 25%                       0.00                       0.00           0.38
# 50%                       0.67                       0.50           0.50
# 75%                       1.00                       1.00           0.62
# max                       1.00                       1.00           1.00
#
#        credit_utilization_ratio  loan_to_income  delinquency_ratio  \
# count                  37488.00        37488.00           37488.00
# mean                       0.44            0.29               0.10
# std                        0.30            0.23               0.17
# min                        0.00            0.00               0.00
# 25%                        0.18            0.11               0.00
# 50%                        0.39            0.20               0.04
# 75%                        0.68            0.51               0.13
# max                        1.00            1.00               1.00
#
#        avg_dpd_per_delinquency  credit_utilization_per_income
# count                 37488.00                       37488.00
# mean                      0.33                           0.14
# std                       0.29                           0.13
# min                       0.00                           0.00
# 25%                       0.00                           0.04
# 50%                       0.43                           0.09
# 75%                       0.57                           0.20
# max                       1.00                           1.00

# %% [markdown]
# #### Same transformation on test set

# %%
X_test = df_test.drop('default', axis='columns')
y_test = df_test['default']

X_test[cols_to_scale] = scaler.transform(X_test[cols_to_scale])
X_test.describe()
# Out:
#            age  number_of_dependants  years_at_current_address  zipcode  \
# count 12497.00              12497.00                  12497.00 12497.00
# mean      0.42                  0.38                      0.50     0.53
# std       0.19                  0.31                      0.30     0.29
# min       0.00                  0.00                      0.00     0.00
# 25%       0.29                  0.00                      0.23     0.33
# 50%       0.42                  0.40                      0.50     0.51
# 75%       0.54                  0.60                      0.77     0.76
# max       1.00                  1.00                      1.00     1.00
#
#        sanction_amount  processing_fee      gst  net_disbursement  \
# count         12497.00        12497.00 12497.00          12497.00
# mean              0.09            0.08     0.08              0.08
# std               0.12            0.11     0.11              0.11
# min              -0.00           -0.00    -0.00             -0.00
# 25%               0.02            0.02     0.02              0.02
# 50%               0.05            0.05     0.05              0.05
# 75%               0.10            0.09     0.09              0.09
# max               0.98            0.96     0.96              0.96
#
#        loan_tenure_months  principal_outstanding  bank_balance_at_application  \
# count            12497.00               12497.00                     12497.00
# mean                 0.38                   0.26                         0.12
# std                  0.23                   0.25                         0.13
# min                  0.00                   0.00                         0.00
# 25%                  0.19                   0.08                         0.03
# 50%                  0.34                   0.20                         0.08
# 75%                  0.55                   0.36                         0.16
# max                  1.00                   1.00                         0.94
#
#        number_of_open_accounts  number_of_closed_accounts  enquiry_count  \
# count                 12497.00                   12497.00       12497.00
# mean                      0.50                       0.50           0.50
# std                       0.37                       0.41           0.25
# min                       0.00                       0.00           0.00
# 25%                       0.00                       0.00           0.38
# 50%                       0.33                       0.50           0.50
# 75%                       0.67                       1.00           0.62
# max                       1.00                       1.00           1.00
#
#        credit_utilization_ratio  loan_to_income  delinquency_ratio  \
# count                  12497.00        12497.00           12497.00
# mean                       0.44            0.29               0.11
# std                        0.30            0.23               0.17
# min                        0.00            0.00               0.00
# 25%                        0.18            0.11               0.00
# 50%                        0.39            0.20               0.04
# 75%                        0.68            0.50               0.13
# max                        1.00            1.00               1.00
#
#        avg_dpd_per_delinquency  credit_utilization_per_income
# count                 12497.00                       12497.00
# mean                      0.33                           0.14
# std                       0.29                           0.13
# min                       0.00                           0.00
# 25%                       0.00                           0.04
# 50%                       0.44                           0.09
# 75%                       0.58                           0.20
# max                       1.00                           0.96

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

def calculate_vif(data):
    vif_df = pd.DataFrame()
    vif_df['Column'] = data.columns
    vif_df['VIF'] = [variance_inflation_factor(data.values,i) for i in range(data.shape[1])]
    return vif_df

# %%
X_train.head(2)
# Out:
#        age gender marital_status employment_status  number_of_dependants  \
# 12746 0.79      M        Married     Self-Employed                  0.60
# 32495 0.50      F         Single          Salaried                  0.00
#
#       residence_type  years_at_current_address       city        state  \
# 12746          Owned                      0.97  Hyderabad    Telangana
# 32495          Owned                      0.87     Mumbai  Maharashtra
#
#        zipcode  ... principal_outstanding bank_balance_at_application  \
# 12746     0.66  ...                  1.00                        0.61
# 32495     0.49  ...                  0.09                        0.03
#
#        number_of_open_accounts  number_of_closed_accounts  enquiry_count  \
# 12746                     1.00                       1.00           0.38
# 32495                     0.67                       0.50           0.50
#
#        credit_utilization_ratio  loan_to_income  delinquency_ratio  \
# 12746                      0.36            0.41               0.13
# 32495                      0.05            0.31               0.06
#
#        avg_dpd_per_delinquency  credit_utilization_per_income
# 12746                     0.59                           0.06
# 32495                     0.62                           0.01
#
# [2 rows x 27 columns]

# %%
vif_df = calculate_vif(X_train[cols_to_scale])
vif_df
# Out:
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
#                            Column    VIF
# 0                             age   5.93
# 1            number_of_dependants   2.73
# 2        years_at_current_address   3.44
# 3                         zipcode   3.83
# 4                 sanction_amount 101.16
# 5                  processing_fee    inf
# 6                             gst    inf
# 7                net_disbursement    inf
# 8              loan_tenure_months   6.35
# 9           principal_outstanding  16.67
# 10    bank_balance_at_application  10.15
# 11        number_of_open_accounts   4.39
# 12      number_of_closed_accounts   2.39
# 13                  enquiry_count   6.44
# 14       credit_utilization_ratio  10.44
# 15                 loan_to_income   8.36
# 16              delinquency_ratio   1.94
# 17        avg_dpd_per_delinquency   2.91
# 18  credit_utilization_per_income   9.15

# %%
features_to_drop_vif = ['sanction_amount', 'processing_fee', 'gst', 'net_disbursement','principal_outstanding']
# Dropping these features because they have high VIF and are not important for the model


X_train_1 = X_train.drop(features_to_drop_vif, axis='columns')
numeric_columns = X_train_1.select_dtypes(['int64', 'float64']).columns
numeric_columns
# Out:
# Index(['age', 'number_of_dependants', 'years_at_current_address', 'zipcode',
#        'loan_tenure_months', 'bank_balance_at_application',
#        'number_of_open_accounts', 'number_of_closed_accounts', 'enquiry_count',
#        'credit_utilization_ratio', 'loan_to_income', 'delinquency_ratio',
#        'avg_dpd_per_delinquency', 'credit_utilization_per_income'],
#       dtype='object')

# %%
vif_df = calculate_vif(X_train_1[numeric_columns])
vif_df
# Out:
#                            Column   VIF
# 0                             age  5.61
# 1            number_of_dependants  2.73
# 2        years_at_current_address  3.43
# 3                         zipcode  3.81
# 4              loan_tenure_months  6.21
# 5     bank_balance_at_application  1.89
# 6         number_of_open_accounts  4.35
# 7       number_of_closed_accounts  2.38
# 8                   enquiry_count  6.42
# 9        credit_utilization_ratio 10.13
# 10                 loan_to_income  6.19
# 11              delinquency_ratio  1.94
# 12        avg_dpd_per_delinquency  2.91
# 13  credit_utilization_per_income  8.70

# %% [markdown]
# All though credit_utilization_ratio has high VIF, we will not drop it since business team has insisted to not drop this important feature

# %%
selected_numeric_features_vif = vif_df.Column.values
selected_numeric_features_vif
# Out:
# array(['age', 'number_of_dependants', 'years_at_current_address',
#        'zipcode', 'loan_tenure_months', 'bank_balance_at_application',
#        'number_of_open_accounts', 'number_of_closed_accounts',
#        'enquiry_count', 'credit_utilization_ratio', 'loan_to_income',
#        'delinquency_ratio', 'avg_dpd_per_delinquency',
#        'credit_utilization_per_income'], dtype=object)

# %%
numeric_columns
# Out:
# Index(['age', 'number_of_dependants', 'years_at_current_address', 'zipcode',
#        'loan_tenure_months', 'bank_balance_at_application',
#        'number_of_open_accounts', 'number_of_closed_accounts', 'enquiry_count',
#        'credit_utilization_ratio', 'loan_to_income', 'delinquency_ratio',
#        'avg_dpd_per_delinquency', 'credit_utilization_per_income'],
#       dtype='object')

# %%
plt.figure(figsize=(12,12))
cm = df_train_3[numeric_columns.append(pd.Index(['default']))].corr()
sns.heatmap(cm, annot=True, fmt='0.2f')
plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Feature Selection: Categorical Features

# %%
X_train_1.head()
# Out:
#        age gender marital_status employment_status  number_of_dependants  \
# 12746 0.79      M        Married     Self-Employed                  0.60
# 32495 0.50      F         Single          Salaried                  0.00
# 43675 0.38      M         Single          Salaried                  0.00
# 9040  0.46      M        Married          Salaried                  0.40
# 13077 0.77      M        Married     Self-Employed                  0.80
#
#       residence_type  years_at_current_address       city        state  \
# 12746          Owned                      0.97  Hyderabad    Telangana
# 32495          Owned                      0.87     Mumbai  Maharashtra
# 43675       Mortgage                      0.83    Chennai   Tamil Nadu
# 9040        Mortgage                      0.97  Bangalore    Karnataka
# 13077          Owned                      0.93       Pune  Maharashtra
#
#        zipcode  ... loan_tenure_months bank_balance_at_application  \
# 12746     0.66  ...               0.42                        0.61
# 32495     0.49  ...               0.83                        0.03
# 43675     0.83  ...               0.49                        0.17
# 9040      0.76  ...               0.64                        0.08
# 13077     0.51  ...               0.17                        0.07
#
#        number_of_open_accounts  number_of_closed_accounts  enquiry_count  \
# 12746                     1.00                       1.00           0.38
# 32495                     0.67                       0.50           0.50
# 43675                     0.00                       0.50           0.38
# 9040                      0.67                       0.00           0.88
# 13077                     0.00                       1.00           0.00
#
#        credit_utilization_ratio  loan_to_income  delinquency_ratio  \
# 12746                      0.36            0.41               0.13
# 32495                      0.05            0.31               0.06
# 43675                      0.00            0.76               0.22
# 9040                       0.88            0.19               0.00
# 13077                      0.72            0.05               0.00
#
#        avg_dpd_per_delinquency  credit_utilization_per_income
# 12746                     0.59                           0.06
# 32495                     0.62                           0.01
# 43675                     0.56                           0.00
# 9040                      0.00                           0.26
# 13077                     0.00                           0.49
#
# [5 rows x 22 columns]

# %% [markdown]
# ### Calculate WOE and IV

# %%
def calculate_woe_iv(df, feature, target):
    grouped = df.groupby(feature)[target].agg(['count','sum'])
    grouped = grouped.rename(columns={'count': 'total', 'sum': 'good'})
    grouped['bad']=grouped['total']-grouped['good']

    total_good = grouped['good'].sum()
    total_bad = grouped['bad'].sum()

    grouped['good_pct'] = grouped['good'] / total_good
    grouped['bad_pct'] = grouped['bad'] / total_bad
    grouped['woe'] = np.log(grouped['good_pct']/ grouped['bad_pct'])
    grouped['iv'] = (grouped['good_pct'] -grouped['bad_pct'])*grouped['woe']

    grouped['woe'] = grouped['woe'].replace([np.inf, -np.inf], 0)
    grouped['iv'] = grouped['iv'].replace([np.inf, -np.inf], 0)

    total_iv = grouped['iv'].sum()

    return grouped, total_iv

grouped, total_iv = calculate_woe_iv(pd.concat([X_train_1, y_train],axis=1), 'loan_purpose', 'default')
grouped
# Out:
#               total  good    bad  good_pct  bad_pct   woe   iv
# loan_purpose
# Auto           7447   327   7120      0.10     0.21 -0.72 0.08
# Education      5620   559   5061      0.17     0.15  0.16 0.00
# Home          11304  1734   9570      0.54     0.28  0.66 0.17
# Personal      13117   603  12514      0.19     0.37 -0.67 0.12

# %%
X_train_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 37488 entries, 12746 to 37784
# Data columns (total 22 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   age                            37488 non-null  float64
#  1   gender                         37488 non-null  object
#  2   marital_status                 37488 non-null  object
#  3   employment_status              37488 non-null  object
#  4   number_of_dependants           37488 non-null  float64
#  5   residence_type                 37488 non-null  object
#  6   years_at_current_address       37488 non-null  float64
#  7   city                           37488 non-null  object
#  8   state                          37488 non-null  object
#  9   zipcode                        37488 non-null  float64
#  10  loan_purpose                   37488 non-null  object
#  11  loan_type                      37488 non-null  object
#  12  loan_tenure_months             37488 non-null  float64
#  13  bank_balance_at_application    37488 non-null  float64
#  14  number_of_open_accounts        37488 non-null  float64
#  15  number_of_closed_accounts      37488 non-null  float64
#  16  enquiry_count                  37488 non-null  float64
#  17  credit_utilization_ratio       37488 non-null  float64
#  18  loan_to_income                 37488 non-null  float64
#  19  delinquency_ratio              37488 non-null  float64
#  20  avg_dpd_per_delinquency        37488 non-null  float64
#  21  credit_utilization_per_income  37488 non-null  float64
# dtypes: float64(14), object(8)
# memory usage: 6.6+ MB

# %%
iv_values = {}

for feature in X_train_1.columns:
    if X_train_1[feature].dtype == 'object':
        _, iv = calculate_woe_iv(pd.concat([X_train_1, y_train],axis=1), feature, 'default' )
    else:
        X_binned = pd.cut(X_train_1[feature], bins=10, labels=False)
        _, iv = calculate_woe_iv(pd.concat([X_binned, y_train],axis=1), feature, 'default' )
    iv_values[feature] = iv

iv_values
# Out:
# {'age': np.float64(0.0890689462679479),
#  'gender': np.float64(0.00047449502170914947),
#  'marital_status': np.float64(0.001129766845390142),
#  'employment_status': np.float64(0.003953046301722585),
#  'number_of_dependants': np.float64(0.0019380899135053508),
#  'residence_type': np.float64(0.246745268718145),
#  'years_at_current_address': np.float64(0.0020800513608156363),
#  'city': np.float64(0.0019059578709781529),
#  'state': np.float64(0.0019005589806779287),
#  'zipcode': np.float64(0.0016677413243392572),
#  'loan_purpose': np.float64(0.3691197842282755),
#  'loan_type': np.float64(0.16319324904149224),
#  'loan_tenure_months': np.float64(0.21893515090196278),
#  'bank_balance_at_application': np.float64(0.0063187993277516365),
#  'number_of_open_accounts': np.float64(0.08463134083005877),
#  'number_of_closed_accounts': np.float64(0.0011964272592421567),
#  'enquiry_count': np.float64(0.007864214085342608),
#  'credit_utilization_ratio': np.float64(2.352965568168245),
#  'loan_to_income': np.float64(0.476415456948364),
#  'delinquency_ratio': np.float64(0.716576108689321),
#  'avg_dpd_per_delinquency': np.float64(0.40151905412190175),
#  'credit_utilization_per_income': np.float64(0.1955737783581886)}

# %%
pd.set_option('display.float_format', lambda x: '{:.3f}'.format(x))

iv_df = pd.DataFrame(list(iv_values.items()), columns=['Feature', 'IV'])
iv_df = iv_df.sort_values(by='IV', ascending=False)
iv_df
# Out:
#                           Feature    IV
# 17       credit_utilization_ratio 2.353
# 19              delinquency_ratio 0.717
# 18                 loan_to_income 0.476
# 20        avg_dpd_per_delinquency 0.402
# 10                   loan_purpose 0.369
# 5                  residence_type 0.247
# 12             loan_tenure_months 0.219
# 21  credit_utilization_per_income 0.196
# 11                      loan_type 0.163
# 0                             age 0.089
# 14        number_of_open_accounts 0.085
# 16                  enquiry_count 0.008
# 13    bank_balance_at_application 0.006
# 3               employment_status 0.004
# 6        years_at_current_address 0.002
# 4            number_of_dependants 0.002
# 7                            city 0.002
# 8                           state 0.002
# 9                         zipcode 0.002
# 15      number_of_closed_accounts 0.001
# 2                  marital_status 0.001
# 1                          gender 0.000

# %%
# select features that has IV > 0.02
selected_features_iv = [feature for feature, iv in iv_values.items() if iv > 0.02]
selected_features_iv
# Out:
# ['age',
#  'residence_type',
#  'loan_purpose',
#  'loan_type',
#  'loan_tenure_months',
#  'number_of_open_accounts',
#  'credit_utilization_ratio',
#  'loan_to_income',
#  'delinquency_ratio',
#  'avg_dpd_per_delinquency',
#  'credit_utilization_per_income']

# %% [markdown]
# ### Feature Encoding

# %%
X_train_reduced = X_train_1[selected_features_iv]
X_test_reduced = X_test[selected_features_iv]

# %%
X_train_encoded = pd.get_dummies(X_train_reduced, drop_first=True)
X_train_encoded.head(3)
# Out:
#         age  loan_tenure_months  number_of_open_accounts  \
# 12746 0.788               0.415                    1.000
# 32495 0.500               0.830                    0.667
# 43675 0.385               0.491                    0.000
#
#        credit_utilization_ratio  loan_to_income  delinquency_ratio  \
# 12746                     0.364           0.415              0.132
# 32495                     0.051           0.307              0.062
# 43675                     0.000           0.759              0.222
#
#        avg_dpd_per_delinquency  credit_utilization_per_income  \
# 12746                    0.590                          0.060
# 32495                    0.620                          0.011
# 43675                    0.560                          0.000
#
#        residence_type_Owned  residence_type_Rented  loan_purpose_Education  \
# 12746                  True                  False                   False
# 32495                  True                  False                    True
# 43675                 False                  False                   False
#
#        loan_purpose_Home  loan_purpose_Personal  loan_type_Unsecured
# 12746               True                  False                False
# 32495              False                  False                False
# 43675               True                  False                False

# %%
X_test_encoded = pd.get_dummies(X_test_reduced, drop_first=True)
X_test_encoded.head(3)
# Out:
#         age  loan_tenure_months  number_of_open_accounts  \
# 19205 0.346               0.755                    0.333
# 15514 0.481               0.226                    1.000
# 30367 0.231               0.547                    0.667
#
#        credit_utilization_ratio  loan_to_income  delinquency_ratio  \
# 19205                     0.990           0.550              0.000
# 15514                     0.323           0.220              0.000
# 30367                     0.828           0.180              0.000
#
#        avg_dpd_per_delinquency  credit_utilization_per_income  \
# 19205                    0.000                          0.127
# 15514                    0.000                          0.089
# 30367                    0.000                          0.263
#
#        residence_type_Owned  residence_type_Rented  loan_purpose_Education  \
# 19205                  True                  False                   False
# 15514                  True                  False                    True
# 30367                  True                  False                   False
#
#        loan_purpose_Home  loan_purpose_Personal  loan_type_Unsecured
# 19205               True                  False                False
# 15514              False                  False                False
# 30367              False                  False                False

# %% [markdown]
# <h3 align="center" style="color:blue">Model Training</h3>

# %% [markdown]
# ### Attempt 1
#
# 1. Logistic Regression, RandomForest & XGB
# 1. No handling of class imbalance

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report

model = LogisticRegression()
model.fit(X_train_encoded, y_train)

y_pred = model.predict(X_test_encoded)
report = classification_report(y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98     11423
#            1       0.85      0.72      0.78      1074
#
#     accuracy                           0.96     12497
#    macro avg       0.91      0.86      0.88     12497
# weighted avg       0.96      0.96      0.96     12497

# %%
feature_importance = model.coef_[0]

# Create a DataFrame for easier handling
coef_df = pd.DataFrame(feature_importance, index=X_train_encoded.columns, columns=['Coefficients'])

# Sort the coefficients for better visualization
coef_df = coef_df.sort_values(by='Coefficients', ascending=True)

# Plotting
plt.figure(figsize=(8, 4))
plt.barh(coef_df.index, coef_df['Coefficients'], color='steelblue')
plt.xlabel('Coefficient Value')
plt.title('Feature Importance in Logistic Regression')
plt.show()

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier()
model.fit(X_train_encoded, y_train)

y_pred = model.predict(X_test_encoded)
report = classification_report(y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98     11423
#            1       0.84      0.71      0.77      1074
#
#     accuracy                           0.96     12497
#    macro avg       0.91      0.85      0.88     12497
# weighted avg       0.96      0.96      0.96     12497

# %%
from xgboost import XGBClassifier

model = XGBClassifier()
model.fit(X_train_encoded, y_train)

y_pred = model.predict(X_test_encoded)
report = classification_report(y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98     11423
#            1       0.82      0.75      0.78      1074
#
#     accuracy                           0.96     12497
#    macro avg       0.90      0.87      0.88     12497
# weighted avg       0.96      0.96      0.96     12497

# %% [markdown]
# Since there is not much difference between XGB and Logistic, we will choose LogisticRegression as a candidate for our RandomizedSearchCV candidate it has a better interpretation.

# %% [markdown]
# #### RandomizedSearch CV for Attempt 1: Logistic Regression

# %%
from sklearn.model_selection import RandomizedSearchCV

param_dist = {
    'C': np.logspace(-4, 4, 20),  # Logarithmically spaced values from 10^-4 to 10^4
    'solver': ['lbfgs', 'saga', 'liblinear', 'newton-cg']   # Algorithm to use in the optimization problem
}

# Create the Logistic Regression model
log_reg = LogisticRegression(max_iter=10000)  # Increased max_iter for convergence

# Set up RandomizedSearchCV
random_search = RandomizedSearchCV(
    estimator=log_reg,
    param_distributions=param_dist,
    n_iter=50,  # Number of parameter settings that are sampled
    scoring='f1',
    cv=3,  # 5-fold cross-validation
    verbose=2,
    random_state=42,  # Set a random state for reproducibility
    n_jobs=-1  # Use all available cores
)

# Fit the RandomizedSearchCV to the training data
random_search.fit(X_train_encoded, y_train)

# Print the best parameters and best score
print(f"Best Parameters: {random_search.best_params_}")
print(f"Best Score: {random_search.best_score_}")

best_model = random_search.best_estimator_
y_pred = best_model.predict(X_test_encoded)
print("Classification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Fitting 3 folds for each of 50 candidates, totalling 150 fits
# [CV] END .............................C=0.0001, solver=lbfgs; total time=   0.0s
# [CV] END .............................C=0.0001, solver=lbfgs; total time=   0.0s
# [CV] END ............C=0.08858667904100823, solver=liblinear; total time=   0.1s
# [CV] END .............................C=0.0001, solver=lbfgs; total time=   0.0s
# [CV] END ...........C=0.012742749857031334, solver=liblinear; total time=   0.1s
# [CV] END ...........C=0.012742749857031334, solver=liblinear; total time=   0.1s
# [CV] END ............C=0.08858667904100823, solver=liblinear; total time=   0.1s
# [CV] END ............C=0.08858667904100823, solver=liblinear; total time=   0.1s
# [CV] END ...........C=0.012742749857031334, solver=liblinear; total time=   0.1s
# [CV] END ............C=0.08858667904100823, solver=newton-cg; total time=   0.0s
# [CV] END ............C=0.08858667904100823, solver=newton-cg; total time=   0.0s
# [CV] END ................C=0.08858667904100823, solver=lbfgs; total time=   0.0s
# [CV] END ............C=0.08858667904100823, solver=newton-cg; total time=   0.1s
# [CV] END ...........C=0.004832930238571752, solver=liblinear; total time=   0.1s
# [CV] END ................C=0.08858667904100823, solver=lbfgs; total time=   0.0s
# [CV] END ................C=0.08858667904100823, solver=lbfgs; total time=   0.0s
# [CV] END ...........C=0.004832930238571752, solver=liblinear; total time=   0.1s
# [CV] END ...........C=0.004832930238571752, solver=liblinear; total time=   0.1s
# [CV] END ..........C=0.0006951927961775605, solver=liblinear; total time=   0.0s
# [CV] END ..........C=0.0006951927961775605, solver=liblinear; total time=   0.0s
# [CV] END ..........C=0.0006951927961775605, solver=liblinear; total time=   0.0s
# [CV] END .............C=0.00026366508987303583, solver=lbfgs; total time=   0.0s
# [CV] END .............C=0.00026366508987303583, solver=lbfgs; total time=   0.0s
# [CV] END .............C=0.00026366508987303583, solver=lbfgs; total time=   0.0s
# [CV] END ..............C=0.0018329807108324356, solver=lbfgs; total time=   0.0s
# [CV] END ..............C=0.0018329807108324356, solver=lbfgs; total time=   0.0s
# [CV] END ...............C=1438.44988828766, solver=liblinear; total time=   0.1s
# [CV] END ...............C=1438.44988828766, solver=liblinear; total time=   0.1s
# [CV] END ..............C=0.0018329807108324356, solver=lbfgs; total time=   0.0s
# [CV] END ...............C=1438.44988828766, solver=liblinear; total time=   0.1s
# [CV] END ..............C=545.5594781168514, solver=newton-cg; total time=   0.0s
# [CV] END ..............C=545.5594781168514, solver=newton-cg; total time=   0.1s
# [CV] END ..............C=545.5594781168514, solver=newton-cg; total time=   0.1s
# [CV] END .................C=0.23357214690901212, solver=saga; total time=   0.1s
# [CV] END .................C=0.23357214690901212, solver=saga; total time=   0.1s
# [CV] END ............C=0.23357214690901212, solver=newton-cg; total time=   0.0s
# [CV] END .................C=0.23357214690901212, solver=saga; total time=   0.1s
# [CV] END ..................C=11.288378916846883, solver=saga; total time=   0.1s
# [CV] END ..................C=11.288378916846883, solver=saga; total time=   0.1s
# [CV] END ..................C=11.288378916846883, solver=saga; total time=   0.1s
# [CV] END ............C=0.23357214690901212, solver=newton-cg; total time=   0.0s
# [CV] END ...................C=1438.44988828766, solver=lbfgs; total time=   0.0s
# [CV] END ............C=0.23357214690901212, solver=newton-cg; total time=   0.0s
# [CV] END ...................C=1438.44988828766, solver=lbfgs; total time=   0.0s
# [CV] END ...................C=1438.44988828766, solver=lbfgs; total time=   0.0s
# [CV] END ...................C=4.281332398719396, solver=saga; total time=   0.1s
# [CV] END ...................C=4.281332398719396, solver=saga; total time=   0.1s
# [CV] END ...................C=4.281332398719396, solver=saga; total time=   0.1s
# [CV] END .............C=29.763514416313132, solver=newton-cg; total time=   0.1s
# [CV] END ...................C=3792.690190732246, solver=saga; total time=   0.1s
# [CV] END ....................C=206.913808111479, solver=saga; total time=   0.1s
# [CV] END ...................C=3792.690190732246, solver=saga; total time=   0.1s
# [CV] END ..................C=1.623776739188721, solver=lbfgs; total time=   0.0s
# [CV] END .............C=29.763514416313132, solver=newton-cg; total time=   0.1s
# [CV] END ....................C=206.913808111479, solver=saga; total time=   0.1s
# [CV] END ....................C=206.913808111479, solver=saga; total time=   0.1s
# [CV] END .............C=29.763514416313132, solver=newton-cg; total time=   0.1s
# [CV] END ...................C=3792.690190732246, solver=saga; total time=   0.2s
# [CV] END ..................C=1.623776739188721, solver=lbfgs; total time=   0.0s
# [CV] END ..................C=1.623776739188721, solver=lbfgs; total time=   0.0s
# [CV] END ..................C=545.5594781168514, solver=lbfgs; total time=   0.0s
# [CV] END ..............C=4.281332398719396, solver=newton-cg; total time=   0.1s
# [CV] END ............C=0.23357214690901212, solver=liblinear; total time=   0.1s
# [CV] END ..................C=545.5594781168514, solver=lbfgs; total time=   0.1s
# [CV] END ............C=0.23357214690901212, solver=liblinear; total time=   0.1s
# [CV] END ...............C=206.913808111479, solver=liblinear; total time=   0.1s
# [CV] END ...............C=0.0006951927961775605, solver=saga; total time=   0.1s
# [CV] END ..............C=1.623776739188721, solver=liblinear; total time=   0.1s
# [CV] END ..............C=0.00026366508987303583, solver=saga; total time=   0.1s
# [CV] END ..............C=4.281332398719396, solver=newton-cg; total time=   0.1s
# [CV] END ...............C=0.0006951927961775605, solver=saga; total time=   0.2s
# [CV] END ..................C=545.5594781168514, solver=lbfgs; total time=   0.0s
# [CV] END ............C=0.23357214690901212, solver=liblinear; total time=   0.1s
# [CV] END ..............C=1.623776739188721, solver=liblinear; total time=   0.1s
# [CV] END ..............C=0.00026366508987303583, solver=saga; total time=   0.2s
# [CV] END ...............C=206.913808111479, solver=liblinear; total time=   0.1s
# [CV] END ..............C=1.623776739188721, solver=liblinear; total time=   0.1s
# [CV] END ...............C=206.913808111479, solver=liblinear; total time=   0.1s
# [CV] END ...............C=0.004832930238571752, solver=lbfgs; total time=   0.0s
# [CV] END ..............C=4.281332398719396, solver=newton-cg; total time=   0.0s
# [CV] END ...............C=0.004832930238571752, solver=lbfgs; total time=   0.0s
# [CV] END ...............C=0.004832930238571752, solver=lbfgs; total time=   0.0s
# [CV] END ..............C=0.00026366508987303583, solver=saga; total time=   0.1s
# [CV] END ..................C=78.47599703514607, solver=lbfgs; total time=   0.0s
# [CV] END ..............C=0.615848211066026, solver=newton-cg; total time=   0.0s
# [CV] END .............C=29.763514416313132, solver=liblinear; total time=   0.1s
# [CV] END .............C=29.763514416313132, solver=liblinear; total time=   0.1s
# [CV] END ...............C=0.0006951927961775605, solver=saga; total time=   0.1s
# [CV] END ..................C=78.47599703514607, solver=lbfgs; total time=   0.0s
# [CV] END ..............C=0.615848211066026, solver=newton-cg; total time=   0.0s
# [CV] END .........C=0.00026366508987303583, solver=newton-cg; total time=   0.0s
# [CV] END ..................C=78.47599703514607, solver=lbfgs; total time=   0.0s
# [CV] END ........................C=10000.0, solver=newton-cg; total time=   0.1s
# [CV] END .........C=0.00026366508987303583, solver=newton-cg; total time=   0.0s
# [CV] END .........C=0.00026366508987303583, solver=newton-cg; total time=   0.0s
# [CV] END ..............C=0.615848211066026, solver=newton-cg; total time=   0.1s
# [CV] END ...........C=0.004832930238571752, solver=newton-cg; total time=   0.0s
# [CV] END ........................C=10000.0, solver=newton-cg; total time=   0.1s
# [CV] END ........................C=10000.0, solver=newton-cg; total time=   0.1s
# [CV] END .............C=29.763514416313132, solver=liblinear; total time=   0.1s
# [CV] END ...........C=0.004832930238571752, solver=newton-cg; total time=   0.0s
# [CV] END .............C=11.288378916846883, solver=liblinear; total time=   0.1s
# [CV] END .............C=11.288378916846883, solver=liblinear; total time=   0.1s
# [CV] END ..................C=4.281332398719396, solver=lbfgs; total time=   0.0s
# [CV] END ..............C=545.5594781168514, solver=liblinear; total time=   0.1s
# [CV] END ..................C=4.281332398719396, solver=lbfgs; total time=   0.0s
# [CV] END ..............C=545.5594781168514, solver=liblinear; total time=   0.1s
# [CV] END ..................C=29.763514416313132, solver=saga; total time=   0.1s
# [CV] END ..................C=4.281332398719396, solver=lbfgs; total time=   0.0s
# [CV] END ............................C=10000.0, solver=lbfgs; total time=   0.0s
# [CV] END ..................C=29.763514416313132, solver=saga; total time=   0.2s
# [CV] END .............C=11.288378916846883, solver=liblinear; total time=   0.1s
# [CV] END ..............C=545.5594781168514, solver=liblinear; total time=   0.1s
# [CV] END .................C=0.03359818286283781, solver=saga; total time=   0.1s
# [CV] END ............................C=10000.0, solver=lbfgs; total time=   0.0s
# [CV] END ...........C=0.004832930238571752, solver=newton-cg; total time=   0.0s
# [CV] END .................C=0.03359818286283781, solver=saga; total time=   0.1s
# [CV] END .........................C=0.0001, solver=newton-cg; total time=   0.0s
# [CV] END ...............C=0.0018329807108324356, solver=saga; total time=   0.1s
# [CV] END ............................C=10000.0, solver=lbfgs; total time=   0.0s
# [CV] END .........................C=0.0001, solver=newton-cg; total time=   0.0s
# [CV] END ..............C=0.0006951927961775605, solver=lbfgs; total time=   0.0s
# [CV] END .........................C=0.0001, solver=newton-cg; total time=   0.0s
# [CV] END ..............C=0.0006951927961775605, solver=lbfgs; total time=   0.0s
# [CV] END ..............C=0.0006951927961775605, solver=lbfgs; total time=   0.0s
# [CV] END .................C=0.03359818286283781, solver=saga; total time=   0.1s
# [CV] END ..................C=29.763514416313132, solver=saga; total time=   0.1s
# [CV] END .........C=0.00026366508987303583, solver=liblinear; total time=   0.0s
# [CV] END ..............C=0.615848211066026, solver=liblinear; total time=   0.1s
# [CV] END .........C=0.00026366508987303583, solver=liblinear; total time=   0.0s
# [CV] END ...............C=0.0018329807108324356, solver=saga; total time=   0.2s
# [CV] END ..................C=0.615848211066026, solver=lbfgs; total time=   0.0s
# [CV] END .........C=0.00026366508987303583, solver=liblinear; total time=   0.0s
# [CV] END ..................C=0.615848211066026, solver=lbfgs; total time=   0.0s
# [CV] END ................C=0.004832930238571752, solver=saga; total time=   0.1s
# [CV] END ................C=0.004832930238571752, solver=saga; total time=   0.1s
# [CV] END ..................C=0.615848211066026, solver=lbfgs; total time=   0.0s
# [CV] END ..................C=3792.690190732246, solver=lbfgs; total time=   0.0s
# [CV] END ..................C=3792.690190732246, solver=lbfgs; total time=   0.0s
# [CV] END ..................C=3792.690190732246, solver=lbfgs; total time=   0.0s
# [CV] END ..............C=0.615848211066026, solver=liblinear; total time=   0.1s
# [CV] END ...................C=545.5594781168514, solver=saga; total time=   0.1s
# [CV] END ...............C=0.0018329807108324356, solver=saga; total time=   0.1s
# [CV] END ..............C=0.615848211066026, solver=liblinear; total time=   0.1s
# [CV] END ..............C=78.47599703514607, solver=liblinear; total time=   0.1s
# [CV] END ...................C=545.5594781168514, solver=saga; total time=   0.2s
# [CV] END ................C=0.004832930238571752, solver=saga; total time=   0.1s
# [CV] END ..............C=78.47599703514607, solver=liblinear; total time=   0.1s
# [CV] END ..............C=78.47599703514607, solver=liblinear; total time=   0.1s
# [CV] END ...................C=545.5594781168514, solver=saga; total time=   0.1s
# Best Parameters: {'solver': 'liblinear', 'C': np.float64(1438.44988828766)}
# Best Score: 0.7584145886719567
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98     11423
#            1       0.83      0.74      0.78      1074
#
#     accuracy                           0.96     12497
#    macro avg       0.90      0.86      0.88     12497
# weighted avg       0.96      0.96      0.96     12497

# %% [markdown]
# #### RandomizedSearch CV for Attempt 1: XGBoost

# %%
from scipy.stats import uniform, randint
from sklearn.model_selection import RandomizedSearchCV

# Define parameter distribution for RandomizedSearchCV
param_dist = {
    'n_estimators': [100, 150, 200, 250, 300],
    'max_depth': [3, 4, 5, 6, 7, 8, 9, 10],
    'learning_rate': [0.01, 0.03, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3],
    'subsample': [0.6, 0.7, 0.8, 0.9, 1.0],
    'colsample_bytree': [0.6, 0.7, 0.8, 0.9, 1.0],
    'scale_pos_weight': [1, 2, 3, 5, 7, 10],
    'reg_alpha': [0.01, 0.1, 0.5, 1.0, 5.0, 10.0],  # L1 regularization term
    'reg_lambda': [0.01, 0.1, 0.5, 1.0, 5.0, 10.0]  # L2 regularization term
}

xgb = XGBClassifier()

random_search = RandomizedSearchCV(estimator=xgb, param_distributions=param_dist, n_iter=100,
                                   scoring='f1', cv=3, verbose=1, n_jobs=-1, random_state=42)

random_search.fit(X_train_encoded, y_train)

# Print the best parameters and best score
print(f"Best Parameters: {random_search.best_params_}")
print(f"Best Score: {random_search.best_score_}")

best_model = random_search.best_estimator_
y_pred = best_model.predict(X_test_encoded)
print("Classification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# Best Parameters: {'subsample': 0.8, 'scale_pos_weight': 2, 'reg_lambda': 1.0, 'reg_alpha': 5.0, 'n_estimators': 100, 'max_depth': 3, 'learning_rate': 0.2, 'colsample_bytree': 0.9}
# Best Score: 0.7874615874528734
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98     11423
#            1       0.76      0.84      0.80      1074
#
#     accuracy                           0.96     12497
#    macro avg       0.87      0.91      0.89     12497
# weighted avg       0.97      0.96      0.96     12497

# %% [markdown]
# ### Attempt 2
#
# 1. Logistic Regression & XGB
# 1. Handle Class Imbalance Using Under Sampling

# %%
from imblearn.under_sampling import RandomUnderSampler

rus = RandomUnderSampler(random_state=42)
X_train_res, y_train_res = rus.fit_resample(X_train_encoded, y_train)
y_train_res.value_counts()
# Out:
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/sklearn/base.py:484: FutureWarning: `BaseEstimator._check_n_features` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_n_features` instead.
#   warnings.warn(
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/sklearn/base.py:493: FutureWarning: `BaseEstimator._check_feature_names` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_feature_names` instead.
#   warnings.warn(
# default
# 0    3223
# 1    3223
# Name: count, dtype: int64

# %%
model = LogisticRegression()
model.fit(X_train_res, y_train_res)

y_pred = model.predict(X_test_encoded)
report = classification_report(y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.91      0.95     11423
#            1       0.51      0.95      0.67      1074
#
#     accuracy                           0.92     12497
#    macro avg       0.75      0.93      0.81     12497
# weighted avg       0.95      0.92      0.93     12497

# %%
model = XGBClassifier(**random_search.best_params_)
model.fit(X_train_res, y_train_res)

y_pred = model.predict(X_test_encoded)
report = classification_report(y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.91      0.95     11423
#            1       0.50      0.98      0.67      1074
#
#     accuracy                           0.92     12497
#    macro avg       0.75      0.95      0.81     12497
# weighted avg       0.96      0.92      0.93     12497

# %% [markdown]
# ### Attempt 3
#
# 1. Logistic Regression
# 1. Handle Class Imbalance Using SMOTE Tomek
# 1. Parameter tunning using optuna

# %%
from imblearn.combine import SMOTETomek

smt = SMOTETomek(random_state=42)
X_train_smt, y_train_smt = smt.fit_resample(X_train_encoded, y_train)
y_train_smt.value_counts()
# Out:
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# default
# 0    34212
# 1    34212
# Name: count, dtype: int64

# %%
model = LogisticRegression()
model.fit(X_train_smt, y_train_smt)

y_pred = model.predict(X_test_encoded)
report = classification_report(y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.93      0.96     11423
#            1       0.56      0.94      0.70      1074
#
#     accuracy                           0.93     12497
#    macro avg       0.78      0.94      0.83     12497
# weighted avg       0.96      0.93      0.94     12497

# %%
import optuna
from sklearn.metrics import make_scorer, f1_score
from sklearn.model_selection import cross_val_score

# %%
# Define the objective function for Optuna
def objective(trial):
    param = {
        'C': trial.suggest_float('C', 1e-4, 1e4, log=True),  # Logarithmically spaced values
        'solver': trial.suggest_categorical('solver', ['lbfgs', 'liblinear', 'saga', 'newton-cg']),  # Solvers
        'tol': trial.suggest_float('tol', 1e-6, 1e-1, log=True),  # Logarithmically spaced values for tolerance
        'class_weight': trial.suggest_categorical('class_weight', [None, 'balanced'])  # Class weights
    }

    model = LogisticRegression(**param, max_iter=10000)

    # Calculate the cross-validated f1_score
    f1_scorer = make_scorer(f1_score, average='macro')
    scores = cross_val_score(model, X_train_smt, y_train_smt, cv=3, scoring=f1_scorer, n_jobs=-1)

    return np.mean(scores)

study_logistic = optuna.create_study(direction='maximize')
study_logistic.optimize(objective, n_trials=50)
# Out:
# [I 2025-09-19 12:19:08,395] A new study created in memory with name: no-name-8af4432d-95af-4b91-af34-cc959ab1d7e3
# [I 2025-09-19 12:19:08,534] Trial 0 finished with value: 0.898875344607366 and parameters: {'C': 0.0007953169170986879, 'solver': 'saga', 'tol': 0.005525193884939259, 'class_weight': 'balanced'}. Best is trial 0 with value: 0.898875344607366.
# [I 2025-09-19 12:19:08,612] Trial 1 finished with value: 0.9160192638695627 and parameters: {'C': 4.450326725703455, 'solver': 'lbfgs', 'tol': 0.009535724149963164, 'class_weight': None}. Best is trial 1 with value: 0.9160192638695627.
# [I 2025-09-19 12:19:08,701] Trial 2 finished with value: 0.9253650700124334 and parameters: {'C': 0.005885962930987284, 'solver': 'newton-cg', 'tol': 0.00015203211499030333, 'class_weight': None}. Best is trial 2 with value: 0.9253650700124334.
# [I 2025-09-19 12:19:08,847] Trial 3 finished with value: 0.9458373608306578 and parameters: {'C': 2198.709253168082, 'solver': 'lbfgs', 'tol': 1.2974827449150704e-06, 'class_weight': 'balanced'}. Best is trial 3 with value: 0.9458373608306578.
# [I 2025-09-19 12:19:09,050] Trial 4 finished with value: 0.9424144093885053 and parameters: {'C': 0.1537428169566403, 'solver': 'saga', 'tol': 1.4146074942594724e-05, 'class_weight': None}. Best is trial 3 with value: 0.9458373608306578.
# [I 2025-09-19 12:19:09,155] Trial 5 finished with value: 0.9442305759892441 and parameters: {'C': 0.42659275162141097, 'solver': 'newton-cg', 'tol': 0.0011410436501590425, 'class_weight': 'balanced'}. Best is trial 3 with value: 0.9458373608306578.
# [I 2025-09-19 12:19:09,237] Trial 6 finished with value: 0.9369265168643843 and parameters: {'C': 32.055068460951325, 'solver': 'lbfgs', 'tol': 0.0023687555154084414, 'class_weight': 'balanced'}. Best is trial 3 with value: 0.9458373608306578.
# [I 2025-09-19 12:19:09,401] Trial 7 finished with value: 0.9411796471944284 and parameters: {'C': 0.17391098465271096, 'solver': 'liblinear', 'tol': 1.672944671804485e-06, 'class_weight': 'balanced'}. Best is trial 3 with value: 0.9458373608306578.
# [I 2025-09-19 12:19:09,571] Trial 8 finished with value: 0.9457746582694453 and parameters: {'C': 1.5811232149114605, 'solver': 'liblinear', 'tol': 0.0006652539725660012, 'class_weight': 'balanced'}. Best is trial 3 with value: 0.9458373608306578.
# [I 2025-09-19 12:19:09,647] Trial 9 finished with value: 0.8568897254228189 and parameters: {'C': 1.1451294010166357, 'solver': 'newton-cg', 'tol': 0.08115661702340939, 'class_weight': None}. Best is trial 3 with value: 0.9458373608306578.
# [I 2025-09-19 12:19:09,801] Trial 10 finished with value: 0.9458373608306578 and parameters: {'C': 7709.791480101568, 'solver': 'lbfgs', 'tol': 1.3754512504656705e-06, 'class_weight': 'balanced'}. Best is trial 3 with value: 0.9458373608306578.
# [I 2025-09-19 12:19:09,954] Trial 11 finished with value: 0.9458227088167753 and parameters: {'C': 8039.292945693607, 'solver': 'lbfgs', 'tol': 1.2400388701301027e-06, 'class_weight': 'balanced'}. Best is trial 3 with value: 0.9458373608306578.
# [I 2025-09-19 12:19:10,139] Trial 12 finished with value: 0.9458519571868065 and parameters: {'C': 3029.528756013641, 'solver': 'lbfgs', 'tol': 1.5685956475514706e-05, 'class_weight': 'balanced'}. Best is trial 12 with value: 0.9458519571868065.
# [I 2025-09-19 12:19:10,262] Trial 13 finished with value: 0.9459833699237737 and parameters: {'C': 213.1653853229772, 'solver': 'lbfgs', 'tol': 3.527051030305251e-05, 'class_weight': 'balanced'}. Best is trial 13 with value: 0.9459833699237737.
# [I 2025-09-19 12:19:10,382] Trial 14 finished with value: 0.9459249300509859 and parameters: {'C': 203.18944269871648, 'solver': 'lbfgs', 'tol': 5.113836866321113e-05, 'class_weight': 'balanced'}. Best is trial 13 with value: 0.9459833699237737.
# [I 2025-09-19 12:19:10,512] Trial 15 finished with value: 0.9458958822520507 and parameters: {'C': 87.89854346137184, 'solver': 'lbfgs', 'tol': 9.559642336063364e-05, 'class_weight': 'balanced'}. Best is trial 13 with value: 0.9459833699237737.
# [I 2025-09-19 12:19:10,686] Trial 16 finished with value: 0.9458957225074309 and parameters: {'C': 135.67877623127814, 'solver': 'lbfgs', 'tol': 1.673809952703186e-05, 'class_weight': 'balanced'}. Best is trial 13 with value: 0.9459833699237737.
# [I 2025-09-19 12:19:11,004] Trial 17 finished with value: 0.9458519996730169 and parameters: {'C': 699.4430231589976, 'solver': 'saga', 'tol': 5.379087642348549e-05, 'class_weight': 'balanced'}. Best is trial 13 with value: 0.9459833699237737.
# [I 2025-09-19 12:19:11,168] Trial 18 finished with value: 0.9460123004446332 and parameters: {'C': 12.429377368564815, 'solver': 'liblinear', 'tol': 0.00030837087248347607, 'class_weight': None}. Best is trial 18 with value: 0.9460123004446332.
# [I 2025-09-19 12:19:11,331] Trial 19 finished with value: 0.9460412607892416 and parameters: {'C': 8.843007441871588, 'solver': 'liblinear', 'tol': 0.00035037291625960736, 'class_weight': None}. Best is trial 19 with value: 0.9460412607892416.
# [I 2025-09-19 12:19:11,479] Trial 20 finished with value: 0.9459977082481797 and parameters: {'C': 14.365446192052438, 'solver': 'liblinear', 'tol': 0.0003058848558328456, 'class_weight': None}. Best is trial 19 with value: 0.9460412607892416.
# [I 2025-09-19 12:19:11,635] Trial 21 finished with value: 0.9460412607892416 and parameters: {'C': 8.727942749854973, 'solver': 'liblinear', 'tol': 0.0003836650491487201, 'class_weight': None}. Best is trial 19 with value: 0.9460412607892416.
# [I 2025-09-19 12:19:11,751] Trial 22 finished with value: 0.929302855294616 and parameters: {'C': 0.02365669649238767, 'solver': 'liblinear', 'tol': 0.0004698232345038233, 'class_weight': None}. Best is trial 19 with value: 0.9460412607892416.
# [I 2025-09-19 12:19:11,939] Trial 23 finished with value: 0.9460412607892416 and parameters: {'C': 8.544773831927957, 'solver': 'liblinear', 'tol': 0.00021216116166424074, 'class_weight': None}. Best is trial 19 with value: 0.9460412607892416.
# [I 2025-09-19 12:19:12,082] Trial 24 finished with value: 0.9459814619315331 and parameters: {'C': 4.855785088506325, 'solver': 'liblinear', 'tol': 0.002217862977052386, 'class_weight': None}. Best is trial 19 with value: 0.9460412607892416.
# [I 2025-09-19 12:19:12,211] Trial 25 finished with value: 0.9458322262271702 and parameters: {'C': 40.741735088068594, 'solver': 'liblinear', 'tol': 0.015655451667133755, 'class_weight': None}. Best is trial 19 with value: 0.9460412607892416.
# [I 2025-09-19 12:19:12,381] Trial 26 finished with value: 0.9459088904851782 and parameters: {'C': 4.726545445084152, 'solver': 'liblinear', 'tol': 0.00012186813512445879, 'class_weight': None}. Best is trial 19 with value: 0.9460412607892416.
# [I 2025-09-19 12:19:12,500] Trial 27 finished with value: 0.9370212017816392 and parameters: {'C': 0.06784243162984163, 'solver': 'liblinear', 'tol': 0.0013415567125702578, 'class_weight': None}. Best is trial 19 with value: 0.9460412607892416.
# [I 2025-09-19 12:19:12,679] Trial 28 finished with value: 0.9448637266389529 and parameters: {'C': 0.6405889601413758, 'solver': 'liblinear', 'tol': 4.861427368461283e-06, 'class_weight': None}. Best is trial 19 with value: 0.9460412607892416.
# [I 2025-09-19 12:19:12,808] Trial 29 finished with value: 0.8574442786296315 and parameters: {'C': 0.0002602399247599207, 'solver': 'saga', 'tol': 0.004026882643535926, 'class_weight': None}. Best is trial 19 with value: 0.9460412607892416.
# [I 2025-09-19 12:19:12,912] Trial 30 finished with value: 0.8942908165977751 and parameters: {'C': 0.0019694621957418714, 'solver': 'liblinear', 'tol': 0.0007980475190846935, 'class_weight': None}. Best is trial 19 with value: 0.9460412607892416.
# [I 2025-09-19 12:19:13,058] Trial 31 finished with value: 0.9460122495717495 and parameters: {'C': 12.900175182535914, 'solver': 'liblinear', 'tol': 0.00020584000140673722, 'class_weight': None}. Best is trial 19 with value: 0.9460412607892416.
# [I 2025-09-19 12:19:13,208] Trial 32 finished with value: 0.9459977082481797 and parameters: {'C': 14.376452426387647, 'solver': 'liblinear', 'tol': 0.0003217222470751829, 'class_weight': None}. Best is trial 19 with value: 0.9460412607892416.
# [I 2025-09-19 12:19:13,362] Trial 33 finished with value: 0.9459371902587801 and parameters: {'C': 3.0191330520501665, 'solver': 'liblinear', 'tol': 9.634054456525028e-05, 'class_weight': None}. Best is trial 19 with value: 0.9460412607892416.
# [I 2025-09-19 12:19:13,523] Trial 34 finished with value: 0.9459102612646525 and parameters: {'C': 32.861857348841035, 'solver': 'liblinear', 'tol': 0.00024358617158051958, 'class_weight': None}. Best is trial 19 with value: 0.9460412607892416.
# [I 2025-09-19 12:19:13,607] Trial 35 finished with value: 0.942212376318979 and parameters: {'C': 427.9201124207279, 'solver': 'newton-cg', 'tol': 0.007293993585023342, 'class_weight': None}. Best is trial 19 with value: 0.9460412607892416.
# [I 2025-09-19 12:19:13,764] Trial 36 finished with value: 0.9459826993619552 and parameters: {'C': 7.246614871617789, 'solver': 'liblinear', 'tol': 0.0004988910680816632, 'class_weight': None}. Best is trial 19 with value: 0.9460412607892416.
# [I 2025-09-19 12:19:13,896] Trial 37 finished with value: 0.9440302651343858 and parameters: {'C': 0.3116253436509382, 'solver': 'saga', 'tol': 0.0012459275784044187, 'class_weight': None}. Best is trial 19 with value: 0.9460412607892416.
# [I 2025-09-19 12:19:14,050] Trial 38 finished with value: 0.945848240831577 and parameters: {'C': 1.8796308925673617, 'solver': 'liblinear', 'tol': 0.00013907752576127396, 'class_weight': None}. Best is trial 19 with value: 0.9460412607892416.
# [I 2025-09-19 12:19:14,133] Trial 39 finished with value: 0.929508647516485 and parameters: {'C': 55.06014975130808, 'solver': 'newton-cg', 'tol': 0.01598504931616188, 'class_weight': None}. Best is trial 19 with value: 0.9460412607892416.
# [I 2025-09-19 12:19:14,246] Trial 40 finished with value: 0.9388141990028283 and parameters: {'C': 0.09595460413066133, 'solver': 'liblinear', 'tol': 0.0027294555252711503, 'class_weight': None}. Best is trial 19 with value: 0.9460412607892416.
# [I 2025-09-19 12:19:14,398] Trial 41 finished with value: 0.9459538784474854 and parameters: {'C': 16.10557290227826, 'solver': 'liblinear', 'tol': 0.00017671395229542996, 'class_weight': None}. Best is trial 19 with value: 0.9460412607892416.
# [I 2025-09-19 12:19:14,542] Trial 42 finished with value: 0.9460560644150208 and parameters: {'C': 11.115415859893087, 'solver': 'liblinear', 'tol': 0.0003293211712097451, 'class_weight': None}. Best is trial 42 with value: 0.9460560644150208.
# [I 2025-09-19 12:19:14,697] Trial 43 finished with value: 0.9455985956246126 and parameters: {'C': 1.2848550331650428, 'solver': 'liblinear', 'tol': 0.0004626064294739876, 'class_weight': None}. Best is trial 42 with value: 0.9460560644150208.
# [I 2025-09-19 12:19:14,855] Trial 44 finished with value: 0.9459972876302881 and parameters: {'C': 7.120364662461871, 'solver': 'liblinear', 'tol': 0.0009268198515440866, 'class_weight': None}. Best is trial 42 with value: 0.9460560644150208.
# [I 2025-09-19 12:19:15,018] Trial 45 finished with value: 0.9458489438014196 and parameters: {'C': 2.3893524700251296, 'solver': 'liblinear', 'tol': 5.756849084303986e-05, 'class_weight': None}. Best is trial 42 with value: 0.9460560644150208.
# [I 2025-09-19 12:19:15,122] Trial 46 finished with value: 0.9458664774117586 and parameters: {'C': 803.0076766266054, 'solver': 'newton-cg', 'tol': 2.304620401978874e-05, 'class_weight': None}. Best is trial 42 with value: 0.9460560644150208.
# [I 2025-09-19 12:19:15,289] Trial 47 finished with value: 0.944833970629638 and parameters: {'C': 0.6126897691079126, 'solver': 'liblinear', 'tol': 7.43084379733012e-06, 'class_weight': None}. Best is trial 42 with value: 0.9460560644150208.
# [I 2025-09-19 12:19:15,441] Trial 48 finished with value: 0.9458521958889229 and parameters: {'C': 63.1799105652032, 'solver': 'saga', 'tol': 0.00038975666519112386, 'class_weight': None}. Best is trial 42 with value: 0.9460560644150208.
# [I 2025-09-19 12:19:15,601] Trial 49 finished with value: 0.9459248591949546 and parameters: {'C': 25.07749226694248, 'solver': 'liblinear', 'tol': 7.992315938527752e-05, 'class_weight': None}. Best is trial 42 with value: 0.9460560644150208.

# %%
print('Best trial:')
trial = study_logistic.best_trial
print('  F1-score: {}'.format(trial.value))
print('  Params: ')
for key, value in trial.params.items():
    print('    {}: {}'.format(key, value))

best_model_logistic = LogisticRegression(**study_logistic.best_params)
best_model_logistic.fit(X_train_smt, y_train_smt)

# Evaluate on the test set
y_pred = best_model_logistic.predict(X_test_encoded)

report = classification_report(y_test, y_pred)
print(report)
# Out:
# Best trial:
#   F1-score: 0.9460560644150208
#   Params:
#     C: 11.115415859893087
#     solver: liblinear
#     tol: 0.0003293211712097451
#     class_weight: None
#               precision    recall  f1-score   support
#
#            0       0.99      0.93      0.96     11423
#            1       0.56      0.95      0.71      1074
#
#     accuracy                           0.93     12497
#    macro avg       0.78      0.94      0.83     12497
# weighted avg       0.96      0.93      0.94     12497

# %% [markdown]
# ### Attempt 4
#
# 1. XGBoost
# 1. Handle Class Imbalance Using SMOTE Tomek
# 1. Parameter tunning using optuna

# %%
# Define the objective function for Optuna
def objective(trial):
    param = {
        'objective': 'binary:logistic',
        'eval_metric': 'logloss',
        'verbosity': 0,
        'booster': 'gbtree',
        'lambda': trial.suggest_float('lambda', 1e-3, 10.0, log=True),
        'alpha': trial.suggest_float('alpha', 1e-3, 10.0, log=True),
        'subsample': trial.suggest_float('subsample', 0.4, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.4, 1.0),
        'max_depth': trial.suggest_int('max_depth', 3, 10),
        'eta': trial.suggest_float('eta', 0.01, 0.3),
        'gamma': trial.suggest_float('gamma', 0, 10),
        'scale_pos_weight': trial.suggest_float('scale_pos_weight', 1, 10),
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 10),
        'max_delta_step': trial.suggest_int('max_delta_step', 0, 10)
    }

    model = XGBClassifier(**param)

    # Calculate the cross-validated f1_score
    f1_scorer = make_scorer(f1_score, average='macro')
    scores = cross_val_score(model, X_train_smt, y_train_smt, cv=3, scoring=f1_scorer, n_jobs=-1)

    return np.mean(scores)

study_xgb = optuna.create_study(direction='maximize')
study_xgb.optimize(objective, n_trials=50)
# Out:
# [I 2025-09-19 12:19:30,586] A new study created in memory with name: no-name-70beb323-3184-4289-a6dd-ba02acc14f79
# [I 2025-09-19 12:19:30,979] Trial 0 finished with value: 0.9579294056296009 and parameters: {'lambda': 0.010127405265102448, 'alpha': 0.013001284233967108, 'subsample': 0.8481032605238957, 'colsample_bytree': 0.834408438716102, 'max_depth': 6, 'eta': 0.07952976470455003, 'gamma': 1.5122441787840257, 'scale_pos_weight': 5.296899365272492, 'min_child_weight': 6, 'max_delta_step': 3}. Best is trial 0 with value: 0.9579294056296009.
# [I 2025-09-19 12:19:31,431] Trial 1 finished with value: 0.967400478847018 and parameters: {'lambda': 0.08615457085179498, 'alpha': 0.0016188831210071785, 'subsample': 0.5107440359011235, 'colsample_bytree': 0.8792727085357601, 'max_depth': 8, 'eta': 0.08579902764625646, 'gamma': 4.742601608852205, 'scale_pos_weight': 2.6232412412209287, 'min_child_weight': 7, 'max_delta_step': 6}. Best is trial 1 with value: 0.967400478847018.
# [I 2025-09-19 12:19:32,007] Trial 2 finished with value: 0.9527242035129105 and parameters: {'lambda': 1.8271386756542767, 'alpha': 0.03915369260427466, 'subsample': 0.46651723681335894, 'colsample_bytree': 0.9529706738343465, 'max_depth': 8, 'eta': 0.04127364719708433, 'gamma': 1.8811120980419083, 'scale_pos_weight': 9.502960503246666, 'min_child_weight': 7, 'max_delta_step': 0}. Best is trial 1 with value: 0.967400478847018.
# [I 2025-09-19 12:19:32,302] Trial 3 finished with value: 0.9623206670243011 and parameters: {'lambda': 0.04435914638214063, 'alpha': 3.2395000349701446, 'subsample': 0.43660637197175944, 'colsample_bytree': 0.4646926728745533, 'max_depth': 9, 'eta': 0.21977666498573994, 'gamma': 9.74503398495458, 'scale_pos_weight': 1.0970903249090422, 'min_child_weight': 6, 'max_delta_step': 0}. Best is trial 1 with value: 0.967400478847018.
# [I 2025-09-19 12:19:32,555] Trial 4 finished with value: 0.9439319875858732 and parameters: {'lambda': 0.07635812356689038, 'alpha': 0.002634334745467887, 'subsample': 0.9615157703382304, 'colsample_bytree': 0.5051319064186013, 'max_depth': 3, 'eta': 0.21774464852468453, 'gamma': 2.166338273989472, 'scale_pos_weight': 7.4564399909092645, 'min_child_weight': 5, 'max_delta_step': 6}. Best is trial 1 with value: 0.967400478847018.
# [I 2025-09-19 12:19:32,871] Trial 5 finished with value: 0.9575052422971863 and parameters: {'lambda': 0.052149628642337395, 'alpha': 1.5501468835783132, 'subsample': 0.7381940704738347, 'colsample_bytree': 0.43363389740165664, 'max_depth': 5, 'eta': 0.19932891182272913, 'gamma': 2.7058345611138734, 'scale_pos_weight': 6.357479707052494, 'min_child_weight': 6, 'max_delta_step': 2}. Best is trial 1 with value: 0.967400478847018.
# [I 2025-09-19 12:19:33,137] Trial 6 finished with value: 0.8976073326728061 and parameters: {'lambda': 2.187783455123165, 'alpha': 0.013081592036555772, 'subsample': 0.5261135329637601, 'colsample_bytree': 0.41559560336293994, 'max_depth': 3, 'eta': 0.06565438115997892, 'gamma': 6.659497541996098, 'scale_pos_weight': 5.581813567274203, 'min_child_weight': 6, 'max_delta_step': 10}. Best is trial 1 with value: 0.967400478847018.
# [I 2025-09-19 12:19:33,505] Trial 7 finished with value: 0.9435185258469225 and parameters: {'lambda': 0.5235517818350143, 'alpha': 0.01580883037581035, 'subsample': 0.7086515706847037, 'colsample_bytree': 0.7865898571598274, 'max_depth': 5, 'eta': 0.05683074134894578, 'gamma': 6.177313860886535, 'scale_pos_weight': 5.625341564089038, 'min_child_weight': 7, 'max_delta_step': 5}. Best is trial 1 with value: 0.967400478847018.
# [I 2025-09-19 12:19:33,940] Trial 8 finished with value: 0.9522757868590078 and parameters: {'lambda': 0.5670615098272452, 'alpha': 0.002031248504857924, 'subsample': 0.8679189591081459, 'colsample_bytree': 0.4139102070610556, 'max_depth': 8, 'eta': 0.054514419571904046, 'gamma': 5.3202075726668046, 'scale_pos_weight': 2.4665002842952473, 'min_child_weight': 3, 'max_delta_step': 8}. Best is trial 1 with value: 0.967400478847018.
# [I 2025-09-19 12:19:34,232] Trial 9 finished with value: 0.9531372532171586 and parameters: {'lambda': 0.03123709918919921, 'alpha': 0.3538086186235072, 'subsample': 0.45225376038083864, 'colsample_bytree': 0.7446800813371462, 'max_depth': 4, 'eta': 0.2120698130831033, 'gamma': 7.73463462633999, 'scale_pos_weight': 8.443598170644487, 'min_child_weight': 9, 'max_delta_step': 0}. Best is trial 1 with value: 0.967400478847018.
# [I 2025-09-19 12:19:34,600] Trial 10 finished with value: 0.9710940988195041 and parameters: {'lambda': 0.0016792856222025015, 'alpha': 0.16496125185739743, 'subsample': 0.5998079001867263, 'colsample_bytree': 0.6264312289602593, 'max_depth': 10, 'eta': 0.28558904191893114, 'gamma': 4.172151080887509, 'scale_pos_weight': 3.2567869297350827, 'min_child_weight': 1, 'max_delta_step': 6}. Best is trial 10 with value: 0.9710940988195041.
# [I 2025-09-19 12:19:34,948] Trial 11 finished with value: 0.9711231802097501 and parameters: {'lambda': 0.001049340644988111, 'alpha': 0.20187818838495222, 'subsample': 0.588803864785806, 'colsample_bytree': 0.604260454839372, 'max_depth': 10, 'eta': 0.2979816526228359, 'gamma': 4.047672223094843, 'scale_pos_weight': 3.395035135233513, 'min_child_weight': 1, 'max_delta_step': 6}. Best is trial 11 with value: 0.9711231802097501.
# [I 2025-09-19 12:19:35,301] Trial 12 finished with value: 0.9714009522599844 and parameters: {'lambda': 0.0011942366741599564, 'alpha': 0.29407844682460554, 'subsample': 0.6097482473399722, 'colsample_bytree': 0.6107408183093993, 'max_depth': 10, 'eta': 0.29832808804654964, 'gamma': 3.783597209217416, 'scale_pos_weight': 3.675054267931745, 'min_child_weight': 1, 'max_delta_step': 8}. Best is trial 12 with value: 0.9714009522599844.
# [I 2025-09-19 12:19:35,877] Trial 13 finished with value: 0.9748700762988897 and parameters: {'lambda': 0.0010347266532676892, 'alpha': 0.5928401897762193, 'subsample': 0.6143541275007511, 'colsample_bytree': 0.622700863871463, 'max_depth': 10, 'eta': 0.2990054889504838, 'gamma': 0.1445922206856034, 'scale_pos_weight': 4.154997267406072, 'min_child_weight': 1, 'max_delta_step': 9}. Best is trial 13 with value: 0.9748700762988897.
# [I 2025-09-19 12:19:36,386] Trial 14 finished with value: 0.9734212203351135 and parameters: {'lambda': 0.004827901682703692, 'alpha': 0.8535188853219412, 'subsample': 0.6206160117540114, 'colsample_bytree': 0.6308665782463845, 'max_depth': 10, 'eta': 0.25789036224329687, 'gamma': 1.0392762060625849, 'scale_pos_weight': 4.480471082399087, 'min_child_weight': 3, 'max_delta_step': 10}. Best is trial 13 with value: 0.9748700762988897.
# [I 2025-09-19 12:19:36,802] Trial 15 finished with value: 0.969096966569991 and parameters: {'lambda': 0.004003411681397672, 'alpha': 1.0574762031615712, 'subsample': 0.6727664152271476, 'colsample_bytree': 0.6825266930612772, 'max_depth': 7, 'eta': 0.14684204372835657, 'gamma': 0.035467719182012886, 'scale_pos_weight': 4.370028758790096, 'min_child_weight': 3, 'max_delta_step': 10}. Best is trial 13 with value: 0.9748700762988897.
# [I 2025-09-19 12:19:37,369] Trial 16 finished with value: 0.9741839905210044 and parameters: {'lambda': 0.00918086044018603, 'alpha': 5.258667906718622, 'subsample': 0.7736897273015649, 'colsample_bytree': 0.5447759980123259, 'max_depth': 9, 'eta': 0.2532400225127293, 'gamma': 0.24277940780332874, 'scale_pos_weight': 1.3586050829358784, 'min_child_weight': 3, 'max_delta_step': 8}. Best is trial 13 with value: 0.9748700762988897.
# [I 2025-09-19 12:19:37,864] Trial 17 finished with value: 0.9706246609183898 and parameters: {'lambda': 0.013715662741049298, 'alpha': 9.697680604068045, 'subsample': 0.7884852204441077, 'colsample_bytree': 0.5303660902252731, 'max_depth': 9, 'eta': 0.15071472625902868, 'gamma': 0.06002384487897228, 'scale_pos_weight': 1.5619418796942672, 'min_child_weight': 4, 'max_delta_step': 8}. Best is trial 13 with value: 0.9748700762988897.
# [I 2025-09-19 12:19:38,329] Trial 18 finished with value: 0.9730408680958327 and parameters: {'lambda': 0.005352486374281137, 'alpha': 6.831921385999136, 'subsample': 0.8043355993359679, 'colsample_bytree': 0.5507764977099395, 'max_depth': 9, 'eta': 0.25637255822757515, 'gamma': 0.7772958617500034, 'scale_pos_weight': 1.8832380379290647, 'min_child_weight': 2, 'max_delta_step': 9}. Best is trial 13 with value: 0.9748700762988897.
# [I 2025-09-19 12:19:38,746] Trial 19 finished with value: 0.9638753079027799 and parameters: {'lambda': 0.017617680488566847, 'alpha': 2.0237420976826965, 'subsample': 0.9922305608810265, 'colsample_bytree': 0.701204929455118, 'max_depth': 7, 'eta': 0.1188089689932221, 'gamma': 3.18552049156573, 'scale_pos_weight': 6.765218583631263, 'min_child_weight': 2, 'max_delta_step': 4}. Best is trial 13 with value: 0.9748700762988897.
# [I 2025-09-19 12:19:39,086] Trial 20 finished with value: 0.9643850910471351 and parameters: {'lambda': 7.725664765128379, 'alpha': 0.5095287966735867, 'subsample': 0.6682588428174413, 'colsample_bytree': 0.5589595218553312, 'max_depth': 9, 'eta': 0.18083800123927765, 'gamma': 8.764621436674124, 'scale_pos_weight': 2.0376518040947245, 'min_child_weight': 4, 'max_delta_step': 7}. Best is trial 13 with value: 0.9748700762988897.
# [I 2025-09-19 12:19:39,586] Trial 21 finished with value: 0.9744452355042704 and parameters: {'lambda': 0.003903621478204288, 'alpha': 0.8192430012104028, 'subsample': 0.6415734247460747, 'colsample_bytree': 0.6769124236877144, 'max_depth': 10, 'eta': 0.2568841254463281, 'gamma': 1.1929589517903354, 'scale_pos_weight': 4.665653995105757, 'min_child_weight': 3, 'max_delta_step': 9}. Best is trial 13 with value: 0.9748700762988897.
# [I 2025-09-19 12:19:40,140] Trial 22 finished with value: 0.9736671393766017 and parameters: {'lambda': 0.003251520135197228, 'alpha': 4.022083761551665, 'subsample': 0.7222926080907788, 'colsample_bytree': 0.693976539666372, 'max_depth': 10, 'eta': 0.25837975350143455, 'gamma': 0.8139256139591823, 'scale_pos_weight': 4.597010334511334, 'min_child_weight': 2, 'max_delta_step': 9}. Best is trial 13 with value: 0.9748700762988897.
# [I 2025-09-19 12:19:40,647] Trial 23 finished with value: 0.9751765532147362 and parameters: {'lambda': 0.002626605741079887, 'alpha': 0.0759121636911164, 'subsample': 0.775685412705293, 'colsample_bytree': 0.6609648958485912, 'max_depth': 9, 'eta': 0.238312815957545, 'gamma': 0.014331495107822168, 'scale_pos_weight': 4.084431329809435, 'min_child_weight': 4, 'max_delta_step': 9}. Best is trial 23 with value: 0.9751765532147362.
# [I 2025-09-19 12:19:41,220] Trial 24 finished with value: 0.9366629921882899 and parameters: {'lambda': 0.002294583554453388, 'alpha': 0.08781681729606139, 'subsample': 0.5261589659722399, 'colsample_bytree': 0.7646916809640457, 'max_depth': 8, 'eta': 0.013340252586910933, 'gamma': 2.607927695273581, 'scale_pos_weight': 3.9455344369423653, 'min_child_weight': 4, 'max_delta_step': 9}. Best is trial 23 with value: 0.9751765532147362.
# [I 2025-09-19 12:19:41,716] Trial 25 finished with value: 0.9739469295240631 and parameters: {'lambda': 0.002619257104089017, 'alpha': 0.06329043612686044, 'subsample': 0.6485785077404536, 'colsample_bytree': 0.6693235905112271, 'max_depth': 10, 'eta': 0.2395695494174597, 'gamma': 1.479475694035439, 'scale_pos_weight': 5.181014879910206, 'min_child_weight': 5, 'max_delta_step': 7}. Best is trial 23 with value: 0.9751765532147362.
# [I 2025-09-19 12:19:42,157] Trial 26 finished with value: 0.9743579389933323 and parameters: {'lambda': 0.19521590673473502, 'alpha': 0.03930929870664055, 'subsample': 0.8939374227639936, 'colsample_bytree': 0.7314345978975386, 'max_depth': 9, 'eta': 0.26635083363208456, 'gamma': 0.9253449088596195, 'scale_pos_weight': 2.8882496593528995, 'min_child_weight': 10, 'max_delta_step': 9}. Best is trial 23 with value: 0.9751765532147362.
# [I 2025-09-19 12:19:42,584] Trial 27 finished with value: 0.970371967482594 and parameters: {'lambda': 0.00706100821942237, 'alpha': 0.1436069918480304, 'subsample': 0.5815046040324277, 'colsample_bytree': 0.8142245258134337, 'max_depth': 7, 'eta': 0.17253232425137605, 'gamma': 2.122830026976182, 'scale_pos_weight': 6.316041459899882, 'min_child_weight': 2, 'max_delta_step': 7}. Best is trial 23 with value: 0.9751765532147362.
# [I 2025-09-19 12:19:42,954] Trial 28 finished with value: 0.9711788063478153 and parameters: {'lambda': 0.022432356507770066, 'alpha': 0.6607197855668804, 'subsample': 0.7502605624897741, 'colsample_bytree': 0.6581450584521779, 'max_depth': 10, 'eta': 0.2743789776364263, 'gamma': 3.1764923281725097, 'scale_pos_weight': 4.972985899031093, 'min_child_weight': 4, 'max_delta_step': 10}. Best is trial 23 with value: 0.9751765532147362.
# [I 2025-09-19 12:19:43,333] Trial 29 finished with value: 0.9709758382090042 and parameters: {'lambda': 0.0016907505209451685, 'alpha': 0.006542210794965228, 'subsample': 0.4015284409679737, 'colsample_bytree': 0.8619448581884097, 'max_depth': 6, 'eta': 0.23158629931786434, 'gamma': 1.5794424681265427, 'scale_pos_weight': 3.966550048730136, 'min_child_weight': 1, 'max_delta_step': 3}. Best is trial 23 with value: 0.9751765532147362.
# [I 2025-09-19 12:19:43,802] Trial 30 finished with value: 0.9709132187599762 and parameters: {'lambda': 0.010342037506708387, 'alpha': 2.088346230203941, 'subsample': 0.8149433584881044, 'colsample_bytree': 0.7283078058202479, 'max_depth': 8, 'eta': 0.1917185607228104, 'gamma': 0.5528973798010421, 'scale_pos_weight': 5.934194797486279, 'min_child_weight': 5, 'max_delta_step': 9}. Best is trial 23 with value: 0.9751765532147362.
# [I 2025-09-19 12:19:44,202] Trial 31 finished with value: 0.9738750699103059 and parameters: {'lambda': 0.20518201666353303, 'alpha': 0.05304230944128201, 'subsample': 0.8851519171982085, 'colsample_bytree': 0.7263078206058892, 'max_depth': 9, 'eta': 0.27894154666732857, 'gamma': 1.1924922860317446, 'scale_pos_weight': 2.861663874764007, 'min_child_weight': 10, 'max_delta_step': 9}. Best is trial 23 with value: 0.9751765532147362.
# [I 2025-09-19 12:19:44,616] Trial 32 finished with value: 0.9741672026934576 and parameters: {'lambda': 0.17634712098752708, 'alpha': 0.029216790455539196, 'subsample': 0.9081338722175397, 'colsample_bytree': 0.5921551262795259, 'max_depth': 9, 'eta': 0.2748136789376632, 'gamma': 1.225345566255101, 'scale_pos_weight': 3.0676395027827796, 'min_child_weight': 8, 'max_delta_step': 8}. Best is trial 23 with value: 0.9751765532147362.
# [I 2025-09-19 12:19:45,072] Trial 33 finished with value: 0.9743142687294707 and parameters: {'lambda': 0.23653000917968164, 'alpha': 0.005991916413533116, 'subsample': 0.8407154511421091, 'colsample_bytree': 0.8048086248180929, 'max_depth': 8, 'eta': 0.23875311389508547, 'gamma': 0.015478174624182856, 'scale_pos_weight': 2.3784683292128914, 'min_child_weight': 10, 'max_delta_step': 10}. Best is trial 23 with value: 0.9751765532147362.
# [I 2025-09-19 12:19:45,433] Trial 34 finished with value: 0.9732581183805963 and parameters: {'lambda': 0.0021413803378298314, 'alpha': 0.09290852794769229, 'subsample': 0.925488767368654, 'colsample_bytree': 0.9352402804945824, 'max_depth': 9, 'eta': 0.2735069378996652, 'gamma': 1.8964017582401467, 'scale_pos_weight': 4.172730803673018, 'min_child_weight': 3, 'max_delta_step': 7}. Best is trial 23 with value: 0.9751765532147362.
# [I 2025-09-19 12:19:45,969] Trial 35 finished with value: 0.9736832985833045 and parameters: {'lambda': 0.7134623699063919, 'alpha': 0.03411764792338779, 'subsample': 0.6935816918593476, 'colsample_bytree': 0.6444627842208206, 'max_depth': 10, 'eta': 0.2363594392918263, 'gamma': 0.8429909291347648, 'scale_pos_weight': 4.876132631968373, 'min_child_weight': 8, 'max_delta_step': 9}. Best is trial 23 with value: 0.9751765532147362.
# [I 2025-09-19 12:19:46,411] Trial 36 finished with value: 0.9677485976648436 and parameters: {'lambda': 0.10691120396881114, 'alpha': 0.023001408930513185, 'subsample': 0.6389274336027584, 'colsample_bytree': 0.48955376331309786, 'max_depth': 8, 'eta': 0.12264441546565642, 'gamma': 2.6367937936915027, 'scale_pos_weight': 3.376332523250877, 'min_child_weight': 5, 'max_delta_step': 8}. Best is trial 23 with value: 0.9751765532147362.
# [I 2025-09-19 12:19:46,903] Trial 37 finished with value: 0.9730680952221236 and parameters: {'lambda': 0.04583383953680172, 'alpha': 0.34134499000857255, 'subsample': 0.557778292086728, 'colsample_bytree': 0.5889156232354965, 'max_depth': 10, 'eta': 0.2153200215074447, 'gamma': 1.6799517044300525, 'scale_pos_weight': 3.704592359359471, 'min_child_weight': 7, 'max_delta_step': 5}. Best is trial 23 with value: 0.9751765532147362.
# [I 2025-09-19 12:19:47,368] Trial 38 finished with value: 0.9736255786653344 and parameters: {'lambda': 0.0010430686374550504, 'alpha': 0.007083836322043745, 'subsample': 0.927764466853318, 'colsample_bytree': 0.9977303837488636, 'max_depth': 9, 'eta': 0.29643885301572553, 'gamma': 0.4906354507182538, 'scale_pos_weight': 7.025443701708176, 'min_child_weight': 4, 'max_delta_step': 10}. Best is trial 23 with value: 0.9751765532147362.
# [I 2025-09-19 12:19:47,833] Trial 39 finished with value: 0.9718376814707819 and parameters: {'lambda': 0.00696291575152313, 'alpha': 1.236228687155039, 'subsample': 0.5584726258472856, 'colsample_bytree': 0.8466871392488109, 'max_depth': 9, 'eta': 0.26475049935080597, 'gamma': 2.138075257840054, 'scale_pos_weight': 9.94732058553557, 'min_child_weight': 2, 'max_delta_step': 9}. Best is trial 23 with value: 0.9751765532147362.
# [I 2025-09-19 12:19:48,172] Trial 40 finished with value: 0.9666634590670902 and parameters: {'lambda': 1.2232182612927383, 'alpha': 0.5665979494395504, 'subsample': 0.7582544302058735, 'colsample_bytree': 0.757957575346559, 'max_depth': 7, 'eta': 0.24654127058963435, 'gamma': 5.09366791619164, 'scale_pos_weight': 5.355965841990115, 'min_child_weight': 8, 'max_delta_step': 1}. Best is trial 23 with value: 0.9751765532147362.
# [I 2025-09-19 12:19:48,585] Trial 41 finished with value: 0.974108919990165 and parameters: {'lambda': 0.2802260186037808, 'alpha': 0.0026770591284485555, 'subsample': 0.8448658148246614, 'colsample_bytree': 0.7940881534890787, 'max_depth': 8, 'eta': 0.22776255102950022, 'gamma': 0.04309878527957138, 'scale_pos_weight': 2.5142371596100666, 'min_child_weight': 10, 'max_delta_step': 10}. Best is trial 23 with value: 0.9751765532147362.
# [I 2025-09-19 12:19:49,011] Trial 42 finished with value: 0.9748550839120145 and parameters: {'lambda': 0.34481633831563147, 'alpha': 0.006799366609070433, 'subsample': 0.8356785124476007, 'colsample_bytree': 0.897863061745747, 'max_depth': 8, 'eta': 0.20476154898357138, 'gamma': 0.5878793010842871, 'scale_pos_weight': 2.0516095578468283, 'min_child_weight': 9, 'max_delta_step': 10}. Best is trial 23 with value: 0.9751765532147362.
# [I 2025-09-19 12:19:49,525] Trial 43 finished with value: 0.974328087888105 and parameters: {'lambda': 0.10077792198493556, 'alpha': 0.04722813069637634, 'subsample': 0.8743973933862009, 'colsample_bytree': 0.8899631125080039, 'max_depth': 9, 'eta': 0.1969294709491278, 'gamma': 0.662398650972385, 'scale_pos_weight': 2.8688148180602147, 'min_child_weight': 9, 'max_delta_step': 9}. Best is trial 23 with value: 0.9751765532147362.
# [I 2025-09-19 12:19:50,012] Trial 44 finished with value: 0.9738460057448751 and parameters: {'lambda': 0.36008637074878946, 'alpha': 0.0011808558429115801, 'subsample': 0.48846401077892754, 'colsample_bytree': 0.9028346542634511, 'max_depth': 10, 'eta': 0.20929289719600802, 'gamma': 1.4553079622684622, 'scale_pos_weight': 1.9851353563074303, 'min_child_weight': 9, 'max_delta_step': 8}. Best is trial 23 with value: 0.9751765532147362.
# [I 2025-09-19 12:19:50,310] Trial 45 finished with value: 0.9684105904408971 and parameters: {'lambda': 1.098233770188839, 'alpha': 0.018498420563745673, 'subsample': 0.8292611587334028, 'colsample_bytree': 0.714108221996307, 'max_depth': 10, 'eta': 0.2838949533063692, 'gamma': 6.3170649261316365, 'scale_pos_weight': 3.650135255352666, 'min_child_weight': 6, 'max_delta_step': 10}. Best is trial 23 with value: 0.9751765532147362.
# [I 2025-09-19 12:19:50,783] Trial 46 finished with value: 0.9720420619261034 and parameters: {'lambda': 3.893784942403362, 'alpha': 0.009953967037980727, 'subsample': 0.7286577920938139, 'colsample_bytree': 0.9925906441088839, 'max_depth': 9, 'eta': 0.2657541178763072, 'gamma': 0.4633175778714147, 'scale_pos_weight': 8.181769698145985, 'min_child_weight': 9, 'max_delta_step': 9}. Best is trial 23 with value: 0.9751765532147362.
# [I 2025-09-19 12:19:51,029] Trial 47 finished with value: 0.9651156101566785 and parameters: {'lambda': 0.13790589669129713, 'alpha': 0.2087408022495808, 'subsample': 0.6973994480555605, 'colsample_bytree': 0.5719539122869017, 'max_depth': 4, 'eta': 0.28899600831963784, 'gamma': 9.946375922405142, 'scale_pos_weight': 1.16004227157032, 'min_child_weight': 10, 'max_delta_step': 7}. Best is trial 23 with value: 0.9751765532147362.
# [I 2025-09-19 12:19:51,469] Trial 48 finished with value: 0.9717047473843476 and parameters: {'lambda': 0.42551383960254036, 'alpha': 0.11467088293800091, 'subsample': 0.9580085763394979, 'colsample_bytree': 0.6330484741196585, 'max_depth': 8, 'eta': 0.1680860031288544, 'gamma': 1.135738266401809, 'scale_pos_weight': 4.7192756901814406, 'min_child_weight': 3, 'max_delta_step': 8}. Best is trial 23 with value: 0.9751765532147362.
# [I 2025-09-19 12:19:51,767] Trial 49 finished with value: 0.9637335334078413 and parameters: {'lambda': 0.06582726177201337, 'alpha': 0.22197923213843615, 'subsample': 0.8671601822896264, 'colsample_bytree': 0.4564610285836972, 'max_depth': 6, 'eta': 0.222989086580979, 'gamma': 7.2149589339614675, 'scale_pos_weight': 4.1844629863946965, 'min_child_weight': 1, 'max_delta_step': 10}. Best is trial 23 with value: 0.9751765532147362.

# %%
print('Best trial:')
trial = study_xgb.best_trial
print('  F1-score: {}'.format(trial.value))
print('  Params: ')
for key, value in trial.params.items():
    print('    {}: {}'.format(key, value))

best_params = study_xgb.best_params
best_model_xgb = XGBClassifier(**best_params)
best_model_xgb.fit(X_train_smt, y_train_smt)

# Evaluate on the test set
y_pred = best_model_xgb.predict(X_test_encoded)

report = classification_report(y_test, y_pred)
print(report)
# Out:
# Best trial:
#   F1-score: 0.9751765532147362
#   Params:
#     lambda: 0.002626605741079887
#     alpha: 0.0759121636911164
#     subsample: 0.775685412705293
#     colsample_bytree: 0.6609648958485912
#     max_depth: 9
#     eta: 0.238312815957545
#     gamma: 0.014331495107822168
#     scale_pos_weight: 4.084431329809435
#     min_child_weight: 4
#     max_delta_step: 9
#               precision    recall  f1-score   support
#
#            0       0.99      0.96      0.97     11423
#            1       0.68      0.88      0.77      1074
#
#     accuracy                           0.95     12497
#    macro avg       0.84      0.92      0.87     12497
# weighted avg       0.96      0.95      0.96     12497

# %%
import shap

# %% [markdown]
# ## Model Evaluation : ROC/AUC

# %%
y_pred = best_model_logistic.predict(X_test_encoded)
report = classification_report(y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.93      0.96     11423
#            1       0.56      0.95      0.71      1074
#
#     accuracy                           0.93     12497
#    macro avg       0.78      0.94      0.83     12497
# weighted avg       0.96      0.93      0.94     12497

# %%
from sklearn.metrics import roc_curve

probabilities = best_model_logistic.predict_proba(X_test_encoded)[:,1]
fpr, tpr, thresholds = roc_curve(y_test, probabilities)

fpr[:5], tpr[:5], thresholds[:5]
# Out:
# (array([0.        , 0.        , 0.        , 0.00008754, 0.00008754]),
#  array([0.        , 0.0009311 , 0.15456238, 0.15456238, 0.16759777]),
#  array([       inf, 1.        , 0.9995452 , 0.99953921, 0.99945021]))

# %%
from sklearn.metrics import auc

area = auc(fpr, tpr)
area
# Out:
# np.float64(0.9837812926352808)

# %%
plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % area)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# ## Model Evaluation : Rankordering, KS statistic, Gini coeff

# %%
probabilities = best_model_logistic.predict_proba(X_test_encoded)[:,1]

df_eval = pd.DataFrame({
    'Default Truth': y_test,
    'Default Probability': probabilities
})
df_eval.head(3)
# Out:
#        Default Truth  Default Probability
# 19205              0                0.513
# 15514              0                0.000
# 30367              0                0.005

# %%
df_eval['Decile'] = pd.qcut(df_eval['Default Probability'], 10, labels=False, duplicates='drop')
df_eval.head(3)
# Out:
#        Default Truth  Default Probability  Decile
# 19205              0                0.513       8
# 15514              0                0.000       2
# 30367              0                0.005       6

# %%
df_eval[df_eval.Decile==8]['Default Probability'].describe()
# Out:
# count   1250.000
# mean       0.481
# std        0.183
# min        0.209
# 25%        0.316
# 50%        0.463
# 75%        0.637
# max        0.820
# Name: Default Probability, dtype: float64

# %%
df_decile = df_eval.groupby('Decile').apply(lambda x: pd.Series({
    'Minimum Probability': x['Default Probability'].min(),
    'Maximum Probability': x['Default Probability'].max(),
    'Events': x['Default Truth'].sum(),
    'Non-events': x['Default Truth'].count() - x['Default Truth'].sum(),
}))
df_decile.reset_index(inplace=True)
df_decile
# Out:
# /var/folders/mp/7dl9lrks6q76s90zsdq13b4m0000gq/T/ipykernel_44853/482895170.py:1: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_decile = df_eval.groupby('Decile').apply(lambda x: pd.Series({
#    Decile  Minimum Probability  Maximum Probability  Events  Non-events
# 0       0                0.000                0.000   0.000    1250.000
# 1       1                0.000                0.000   0.000    1250.000
# 2       2                0.000                0.000   0.000    1249.000
# 3       3                0.000                0.000   0.000    1250.000
# 4       4                0.000                0.001   0.000    1250.000
# 5       5                0.001                0.004   0.000    1249.000
# 6       6                0.004                0.027   2.000    1248.000
# 7       7                0.027                0.209  13.000    1236.000
# 8       8                0.209                0.820 158.000    1092.000
# 9       9                0.821                1.000 901.000     349.000

# %%
df_decile['Event Rate'] = df_decile['Events']*100 / (df_decile['Events']+df_decile['Non-events'])
df_decile['Non-event Rate'] = df_decile['Non-events']*100 / (df_decile['Events']+df_decile['Non-events'])
df_decile
# Out:
#    Decile  Minimum Probability  Maximum Probability  Events  Non-events  \
# 0       0                0.000                0.000   0.000    1250.000
# 1       1                0.000                0.000   0.000    1250.000
# 2       2                0.000                0.000   0.000    1249.000
# 3       3                0.000                0.000   0.000    1250.000
# 4       4                0.000                0.001   0.000    1250.000
# 5       5                0.001                0.004   0.000    1249.000
# 6       6                0.004                0.027   2.000    1248.000
# 7       7                0.027                0.209  13.000    1236.000
# 8       8                0.209                0.820 158.000    1092.000
# 9       9                0.821                1.000 901.000     349.000
#
#    Event Rate  Non-event Rate
# 0       0.000         100.000
# 1       0.000         100.000
# 2       0.000         100.000
# 3       0.000         100.000
# 4       0.000         100.000
# 5       0.000         100.000
# 6       0.160          99.840
# 7       1.041          98.959
# 8      12.640          87.360
# 9      72.080          27.920

# %%
df_decile = df_decile.sort_values(by='Decile', ascending=False).reset_index(drop=True)
df_decile
# Out:
#    Decile  Minimum Probability  Maximum Probability  Events  Non-events  \
# 0       9                0.821                1.000 901.000     349.000
# 1       8                0.209                0.820 158.000    1092.000
# 2       7                0.027                0.209  13.000    1236.000
# 3       6                0.004                0.027   2.000    1248.000
# 4       5                0.001                0.004   0.000    1249.000
# 5       4                0.000                0.001   0.000    1250.000
# 6       3                0.000                0.000   0.000    1250.000
# 7       2                0.000                0.000   0.000    1249.000
# 8       1                0.000                0.000   0.000    1250.000
# 9       0                0.000                0.000   0.000    1250.000
#
#    Event Rate  Non-event Rate
# 0      72.080          27.920
# 1      12.640          87.360
# 2       1.041          98.959
# 3       0.160          99.840
# 4       0.000         100.000
# 5       0.000         100.000
# 6       0.000         100.000
# 7       0.000         100.000
# 8       0.000         100.000
# 9       0.000         100.000

# %%
df_decile['Cum Events'] =  df_decile['Events'].cumsum()
df_decile['Cum Non-events'] =  df_decile['Non-events'].cumsum()
df_decile
# Out:
#    Decile  Minimum Probability  Maximum Probability  Events  Non-events  \
# 0       9                0.821                1.000 901.000     349.000
# 1       8                0.209                0.820 158.000    1092.000
# 2       7                0.027                0.209  13.000    1236.000
# 3       6                0.004                0.027   2.000    1248.000
# 4       5                0.001                0.004   0.000    1249.000
# 5       4                0.000                0.001   0.000    1250.000
# 6       3                0.000                0.000   0.000    1250.000
# 7       2                0.000                0.000   0.000    1249.000
# 8       1                0.000                0.000   0.000    1250.000
# 9       0                0.000                0.000   0.000    1250.000
#
#    Event Rate  Non-event Rate  Cum Events  Cum Non-events
# 0      72.080          27.920     901.000         349.000
# 1      12.640          87.360    1059.000        1441.000
# 2       1.041          98.959    1072.000        2677.000
# 3       0.160          99.840    1074.000        3925.000
# 4       0.000         100.000    1074.000        5174.000
# 5       0.000         100.000    1074.000        6424.000
# 6       0.000         100.000    1074.000        7674.000
# 7       0.000         100.000    1074.000        8923.000
# 8       0.000         100.000    1074.000       10173.000
# 9       0.000         100.000    1074.000       11423.000

# %%
df_decile['Cum Event Rate'] = df_decile['Cum Events'] * 100 / df_decile['Events'].sum()
df_decile['Cum Non-event Rate'] = df_decile['Cum Non-events']*100 / df_decile['Non-events'].sum()
df_decile
# Out:
#    Decile  Minimum Probability  Maximum Probability  Events  Non-events  \
# 0       9                0.821                1.000 901.000     349.000
# 1       8                0.209                0.820 158.000    1092.000
# 2       7                0.027                0.209  13.000    1236.000
# 3       6                0.004                0.027   2.000    1248.000
# 4       5                0.001                0.004   0.000    1249.000
# 5       4                0.000                0.001   0.000    1250.000
# 6       3                0.000                0.000   0.000    1250.000
# 7       2                0.000                0.000   0.000    1249.000
# 8       1                0.000                0.000   0.000    1250.000
# 9       0                0.000                0.000   0.000    1250.000
#
#    Event Rate  Non-event Rate  Cum Events  Cum Non-events  Cum Event Rate  \
# 0      72.080          27.920     901.000         349.000          83.892
# 1      12.640          87.360    1059.000        1441.000          98.603
# 2       1.041          98.959    1072.000        2677.000          99.814
# 3       0.160          99.840    1074.000        3925.000         100.000
# 4       0.000         100.000    1074.000        5174.000         100.000
# 5       0.000         100.000    1074.000        6424.000         100.000
# 6       0.000         100.000    1074.000        7674.000         100.000
# 7       0.000         100.000    1074.000        8923.000         100.000
# 8       0.000         100.000    1074.000       10173.000         100.000
# 9       0.000         100.000    1074.000       11423.000         100.000
#
#    Cum Non-event Rate
# 0               3.055
# 1              12.615
# 2              23.435
# 3              34.361
# 4              45.295
# 5              56.237
# 6              67.180
# 7              78.114
# 8              89.057
# 9             100.000

# %%
df_decile['KS'] = abs(df_decile['Cum Event Rate'] - df_decile['Cum Non-event Rate'])
df_decile
# Out:
#    Decile  Minimum Probability  Maximum Probability  Events  Non-events  \
# 0       9                0.821                1.000 901.000     349.000
# 1       8                0.209                0.820 158.000    1092.000
# 2       7                0.027                0.209  13.000    1236.000
# 3       6                0.004                0.027   2.000    1248.000
# 4       5                0.001                0.004   0.000    1249.000
# 5       4                0.000                0.001   0.000    1250.000
# 6       3                0.000                0.000   0.000    1250.000
# 7       2                0.000                0.000   0.000    1249.000
# 8       1                0.000                0.000   0.000    1250.000
# 9       0                0.000                0.000   0.000    1250.000
#
#    Event Rate  Non-event Rate  Cum Events  Cum Non-events  Cum Event Rate  \
# 0      72.080          27.920     901.000         349.000          83.892
# 1      12.640          87.360    1059.000        1441.000          98.603
# 2       1.041          98.959    1072.000        2677.000          99.814
# 3       0.160          99.840    1074.000        3925.000         100.000
# 4       0.000         100.000    1074.000        5174.000         100.000
# 5       0.000         100.000    1074.000        6424.000         100.000
# 6       0.000         100.000    1074.000        7674.000         100.000
# 7       0.000         100.000    1074.000        8923.000         100.000
# 8       0.000         100.000    1074.000       10173.000         100.000
# 9       0.000         100.000    1074.000       11423.000         100.000
#
#    Cum Non-event Rate     KS
# 0               3.055 80.837
# 1              12.615 85.988
# 2              23.435 76.379
# 3              34.361 65.639
# 4              45.295 54.705
# 5              56.237 43.763
# 6              67.180 32.820
# 7              78.114 21.886
# 8              89.057 10.943
# 9             100.000  0.000

# %% [markdown]
# To assess whether rank ordering is followed, we should look at whether higher deciles (those with higher predicted probabilities) have higher event rates compared to lower deciles. Rank ordering means that as you move from the top decile to the bottom decile, the event rate should generally decrease.
#
# Non-Events - termed as good (customers) who do not default. Events - termed as bad (customers) who default.
#
# Events and Non-Events terms are interchanged based on usecase to usecase.
#
# eg: for marketing usecase, which customer to reach out (who will take loan based on offers) will be events - here it will termed as good, and the customers who will not take loans will be non-events (bad).
#
# **Insights from the Decile Table**
#
# 1. Top Deciles
#
# * The first decile (Decile 9) has a high event rate of 72.00% and a non-event rate of 28.00%. This indicates that the model is highly confident in predicting events in this decile.
# * The second decile (Decile 8) also shows a significant event rate of 12.72%, with a cumulative event rate reaching 98.6%.
#
# 2. Middle Deciles:
#
# * Deciles 7 and 6 show a significant drop in event rates
#
# 3. Lower Deciles:
#
# * Deciles 5 to 0 show zero events, with all predictions being non-events. These deciles collectively have a non-event rate of 100%.
#
# 4. KS Statistic:
#
# * The KS statistic, which is the maximum difference between cumulative event rates and cumulative non-event rates, is highest at Decile 8 with a value of 85.98%. This suggests that the model performs best at distinguishing between events and non-events up to this decile.
#
# * The KS value gradually decreases in the following deciles, indicating a decrease in model performance for distinguishing between events and non-events.
#
# **KS Value**
#
# The highest KS value is 85.98%, found at Decile 8. This indicates that the model's performance in distinguishing between events and non-events is most significant at this decile. (If KS is in top 3 decile and score above 40, it is considered a good predictive model.)

# %%
gini_coefficient = 2 * area - 1

print("AUC:", area)
print("Gini Coefficient:", gini_coefficient)
# Out:
# AUC: 0.9837812926352808
# Gini Coefficient: 0.9675625852705616

# %% [markdown]
# AUC of 0.98: The model is very good at distinguishing between events and non-events.
#
# Gini coefficient of 0.96: This further confirms that the model is highly effective in its predictions, with almost perfect rank ordering capability.
#
# The Gini coefficient ranges from -1 to 1, where a value closer to 1 signifies a perfect model, 0 indicates a model with no discriminative power, and -1 signifies a perfectly incorrect model.

# %% [markdown]
# #### Finalize The Model and Visualize Feature Importance

# %%
final_model = best_model_logistic

feature_importance = final_model.coef_[0]

# Create a DataFrame for easier handling
coef_df = pd.DataFrame(feature_importance, index=X_train_encoded.columns, columns=['Coefficients'])

# Sort the coefficients for better visualization
coef_df = coef_df.sort_values(by='Coefficients', ascending=True)

# Plotting
plt.figure(figsize=(8, 4))
plt.barh(coef_df.index, coef_df['Coefficients'], color='steelblue')
plt.xlabel('Coefficient Value')
plt.title('Feature Importance in Logistic Regression')
plt.show()

# %% [markdown]
# ### Save the Model

# %%
X_test_encoded.head(2)
# Out:
#         age  loan_tenure_months  number_of_open_accounts  \
# 19205 0.346               0.755                    0.333
# 15514 0.481               0.226                    1.000
#
#        credit_utilization_ratio  loan_to_income  delinquency_ratio  \
# 19205                     0.990           0.550              0.000
# 15514                     0.323           0.220              0.000
#
#        avg_dpd_per_delinquency  credit_utilization_per_income  \
# 19205                    0.000                          0.127
# 15514                    0.000                          0.089
#
#        residence_type_Owned  residence_type_Rented  loan_purpose_Education  \
# 19205                  True                  False                   False
# 15514                  True                  False                    True
#
#        loan_purpose_Home  loan_purpose_Personal  loan_type_Unsecured
# 19205               True                  False                False
# 15514              False                  False                False

# %%
X_test_encoded.columns
# Out:
# Index(['age', 'loan_tenure_months', 'number_of_open_accounts',
#        'credit_utilization_ratio', 'loan_to_income', 'delinquency_ratio',
#        'avg_dpd_per_delinquency', 'credit_utilization_per_income',
#        'residence_type_Owned', 'residence_type_Rented',
#        'loan_purpose_Education', 'loan_purpose_Home', 'loan_purpose_Personal',
#        'loan_type_Unsecured'],
#       dtype='object')

# %%
cols_to_scale
# Out:
# Index(['age', 'number_of_dependants', 'years_at_current_address', 'zipcode',
#        'sanction_amount', 'processing_fee', 'gst', 'net_disbursement',
#        'loan_tenure_months', 'principal_outstanding',
#        'bank_balance_at_application', 'number_of_open_accounts',
#        'number_of_closed_accounts', 'enquiry_count',
#        'credit_utilization_ratio', 'loan_to_income', 'delinquency_ratio',
#        'avg_dpd_per_delinquency', 'credit_utilization_per_income'],
#       dtype='object')

# %%
X_train_encoded.columns
# Out:
# Index(['age', 'loan_tenure_months', 'number_of_open_accounts',
#        'credit_utilization_ratio', 'loan_to_income', 'delinquency_ratio',
#        'avg_dpd_per_delinquency', 'credit_utilization_per_income',
#        'residence_type_Owned', 'residence_type_Rented',
#        'loan_purpose_Education', 'loan_purpose_Home', 'loan_purpose_Personal',
#        'loan_type_Unsecured'],
#       dtype='object')

# %%
from joblib import dump

model_data = {
    'model': final_model,
    'features': X_train_encoded.columns,
    'scaler': scaler,
    'cols_to_scale': cols_to_scale
}
dump(model_data, 'artifacts/model_data.joblib')
# Out:
# ['artifacts/model_data.joblib']

# %%
final_model.coef_, final_model.intercept_
# Out:
# (array([[-0.18151697,  0.63433652,  1.20130947, 15.62475318, 18.34608618,
#          14.16334245,  1.96411834,  3.00081894, -1.86273174,  1.86075035,
#           1.15900464, -3.35333495,  0.88482518,  0.88482518]]),
#  array([-21.49201781]))

# %% [markdown]
# ### Exercise

# %% [markdown]
# ### Exercise Attempt 1 - Bayesian Search with logistic regression

# %%
# !pip install bayesian-optimization scikit-learn
# Out:
# Collecting bayesian-optimization
#   Downloading bayesian_optimization-3.1.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: scikit-learn in /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages (1.6.1)
# Collecting colorama>=0.4.6 (from bayesian-optimization)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: numpy>=1.25 in /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages (from bayesian-optimization) (2.0.2)
# Requirement already satisfied: scipy>=1.0.0 in /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages (from bayesian-optimization) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages (from scikit-learn) (3.6.0)
# Downloading bayesian_optimization-3.1.0-py3-none-any.whl (36 kB)
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Installing collected packages: colorama, bayesian-optimization
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [bayesian-optimization]
# Successfully installed bayesian-optimization-3.1.0 colorama-0.4.6

# %%
from bayes_opt import BayesianOptimization

# %%
# Define the function to optimize
def optimize_log_reg(C, max_iter):
    model = LogisticRegression(C=C, max_iter=int(max_iter), solver='liblinear')
    # Perform 5-fold cross-validation
    scores = cross_val_score(model, X_train_encoded, y_train, cv=5, scoring='roc_auc')
    # We want to maximize the AUC-ROC score
    return scores.mean()

# %%
# Define the parameter space
param_bounds = {
    'C': (0.001, 10.0),
    'max_iter': (50, 500)
}

# %%
# Initialize the Bayesian optimizer
optimizer = BayesianOptimization(
    f=optimize_log_reg,
    pbounds=param_bounds,
    random_state=42
)

# %%
# Perform the optimization
optimizer.maximize(init_points=10, n_iter=50)
# Out:
# |   iter    |  target   |     C     | max_iter  |
# -------------------------------------------------
# | 1         | 0.9827020 | 3.7460266 | 477.82143 |
# | 2         | 0.9827333 | 7.3202074 | 319.39631 |
# | 3         | 0.9825491 | 1.5610303 | 120.19753 |
# | 4         | 0.9819636 | 0.5817780 | 439.77926 |
# | 5         | 0.9827281 | 6.0115490 | 368.63266 |
# | 6         | 0.9804210 | 0.2068243 | 486.45943 |
# | 7         | 0.9827348 | 8.3245939 | 145.55259 |
# | 8         | 0.9825908 | 1.8190678 | 132.53202 |
# | 9         | 0.9826827 | 3.0431181 | 286.14039 |
# | 10        | 0.9827108 | 4.3200182 | 181.05311 |
# | 11        | 0.9827345 | 7.8519744 | 118.46654 |
# | 12        | 0.9827383 | 9.9913716 | 144.91808 |
# | 13        | 0.9827312 | 6.5510892 | 471.05374 |
# | 14        | 0.9827104 | 4.4255519 | 310.31656 |
# | 15        | 0.9827065 | 4.0940638 | 298.40183 |
# | 16        | 0.9827382 | 9.9417871 | 109.00352 |
# | 17        | 0.9813943 | 0.3565494 | 106.58386 |
# | 18        | 0.9827383 | 9.9035271 | 291.36659 |
# | 19        | 0.9827380 | 9.9568617 | 304.44970 |
# | 20        | 0.9826544 | 2.5557369 | 359.10299 |
# | 21        | 0.9827381 | 9.7740260 | 155.86120 |
# | 22        | 0.9827332 | 7.3342089 | 167.96099 |
# | 23        | 0.9813928 | 0.3565258 | 159.81810 |
# | 24        | 0.9827380 | 9.9644197 | 175.73782 |
# | 25        | 0.9827382 | 9.9074518 | 280.00562 |
# | 26        | 0.9825816 | 1.7569860 | 274.83123 |
# | 27        | 0.9812921 | 0.3337402 | 325.91740 |
# | 28        | 0.9824251 | 1.1473422 | 174.03995 |
# | 29        | 0.9827387 | 9.8734263 | 126.93253 |
# | 30        | 0.9827381 | 9.6927418 | 188.57610 |
# | 31        | 0.9802701 | 0.1933762 | 190.08194 |
# | 32        | 0.9827382 | 9.9857832 | 182.60339 |
# | 33        | 0.9827380 | 9.9622143 | 135.32406 |
# | 34        | 0.9795659 | 0.1453399 | 375.79544 |
# | 35        | 0.9827381 | 10.0      | 362.81226 |
# | 36        | 0.9827382 | 9.9023369 | 269.32594 |
# | 37        | 0.9826357 | 2.2621946 | 262.85486 |
# | 38        | 0.9827381 | 9.6643677 | 256.38772 |
# | 39        | 0.9823914 | 1.0594712 | 251.14267 |
# | 40        | 0.9809489 | 0.2713691 | 463.33372 |
# | 41        | 0.9827381 | 10.0      | 476.69571 |
# | 42        | 0.9827381 | 9.6639797 | 351.01043 |
# | 43        | 0.9809973 | 0.2785991 | 348.02877 |
# | 44        | 0.9827380 | 9.7264206 | 243.99264 |
# | 45        | 0.9827380 | 9.6987534 | 234.33873 |
# | 46        | 0.9825204 | 1.4380509 | 237.85852 |
# | 47        | 0.9827118 | 4.5475643 | 225.82632 |
# | 48        | 0.9827370 | 9.2316946 | 216.95141 |
# | 49        | 0.9777291 | 0.0834468 | 217.05437 |
# | 50        | 0.9827381 | 10.0      | 226.79144 |
# | 51        | 0.9822280 | 0.8031819 | 141.34723 |
# | 52        | 0.9827381 | 10.0      | 313.17100 |
# | 53        | 0.9827367 | 9.1530476 | 50.220005 |
# | 54        | 0.9821107 | 0.6878765 | 53.041808 |
# | 55        | 0.9827383 | 9.7885649 | 59.975763 |
# | 56        | 0.9827379 | 9.7333021 | 68.909553 |
# | 57        | 0.9825755 | 1.7358963 | 66.034917 |
# | 58        | 0.9827139 | 4.7970142 | 76.267750 |
# | 59        | 0.9827385 | 9.8770907 | 83.994580 |
# | 60        | 0.9820155 | 0.6176282 | 85.297708 |
# =================================================

# %%
# Extract the best parameters
best_params = optimizer.max['params']
best_params['max_iter'] = int(best_params['max_iter'])

# %%
# Train the final model with the best parameters
final_model = LogisticRegression(**best_params, solver='liblinear')
final_model.fit(X_train_encoded, y_train)
# Out:
# LogisticRegression(C=np.float64(9.873426315108668), max_iter=126,
#                    solver='liblinear')

# %%
# Evaluate the final model on the test set
y_pred = final_model.predict(X_test_encoded)
y_prob = final_model.predict_proba(X_test_encoded)[:, 1]

# %%
# Print the classification report and AUC-ROC score
from sklearn.metrics import classification_report, roc_auc_score

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98     11423
#            1       0.84      0.74      0.79      1074
#
#     accuracy                           0.97     12497
#    macro avg       0.91      0.86      0.88     12497
# weighted avg       0.96      0.97      0.96     12497

# %%
print("AUC-ROC Score:", roc_auc_score(y_test, y_pred))
# Out:
# AUC-ROC Score: 0.8621056116812253

# %% [markdown]
# ### Exercise Attempt 2 - XGBoost with grid search

# %%
from sklearn.model_selection import GridSearchCV

# %%
# Define the parameter grid for XGBoost
param_grid = {
    'max_depth': [3, 4, 5],
    'learning_rate': [0.01, 0.05, 0.1],
    'n_estimators': [50, 100, 200],
    'subsample': [0.8, 0.9, 1.0],
    'colsample_bytree': [0.8, 0.9, 1.0]
}

model = XGBClassifier(use_label_encoder=False, eval_metric='logloss')

# Initialize GridSearchCV
grid_search = GridSearchCV(
    estimator=model,
    param_grid=param_grid,
    scoring='roc_auc',
    cv=5,
    n_jobs=-1
)

# %%
# Fit GridSearchCV
grid_search.fit(X_train_encoded, y_train)
# Out:
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:48] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:48] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:48] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:48] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:48] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:48] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:48] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:48] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:48] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:48] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:48] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:48] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:48] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:48] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:48] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:48] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:48] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:48] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:48] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:48] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:48] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:48] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:48] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:48] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:48] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:48] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:48] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:48] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:48] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:48] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:48] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:48] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:48] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:48] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:48] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:48] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:48] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:48] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:48] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:48] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:49] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:49] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:49] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:49] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:49] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:49] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:49] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:49] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:49] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:49] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:49] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:49] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:49] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:49] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:49] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:49] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:49] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:49] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:49] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:49] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:49] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:49] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:49] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:49] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:49] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:49] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:49] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:49] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:49] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:49] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:49] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:49] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:49] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:49] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:49] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:49] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:49] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:49] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:49] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:49] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:49] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:49] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:49] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:50] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:50] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:50] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:50] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:50] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:50] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:50] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:50] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:50] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:50] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:50] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:50] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:50] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:50] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:50] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:50] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:50] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:50] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:50] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:50] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:50] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:50] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:50] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:50] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:50] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:50] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:50] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:50] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:50] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:50] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:50] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:50] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:51] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:51] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:51] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:51] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:51] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:51] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:51] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:51] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:51] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:51] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:51] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:51] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:51] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:51] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:51] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:51] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:51] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:51] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:51] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:51] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:51] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:51] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:51] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:51] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:51] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:51] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:51] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:51] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:51] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:51] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:51] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:51] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:51] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:51] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:52] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:52] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:52] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:52] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:52] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:52] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:52] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:52] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:52] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:52] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:52] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:52] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:52] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:52] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:36:52] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# ...
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:37:19] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:37:19] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:37:19] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:37:20] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:37:20] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:37:20] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:37:20] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:37:20] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:37:20] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:37:20] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:37:20] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:37:20] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:37:20] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:37:20] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:37:20] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:37:20] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:37:20] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:37:20] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:37:20] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:37:20] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:37:20] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:37:20] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:37:20] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:37:20] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:37:20] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:37:20] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:37:20] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:37:20] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:37:20] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:37:20] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:37:20] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:37:20] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:37:20] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:37:20] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:37:20] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:37:20] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:37:20] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:37:20] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:37:20] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:37:21] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:37:21] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:37:21] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:37:21] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:37:21] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:37:21] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:37:21] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:37:21] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:37:21] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [12:37:21] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# GridSearchCV(cv=5,
#              estimator=XGBClassifier(base_score=None, booster=None,
#                                      callbacks=None, colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None, device=None,
#                                      early_stopping_rounds=None,
#                                      enable_categorical=False,
#                                      eval_metric='logloss', feature_types=None,
#                                      gamma=None, grow_policy=None,
#                                      importance_type=None,
#                                      interaction_constraints=None,
#                                      learning_rate=...
#                                      max_leaves=None, min_child_weight=None,
#                                      missing=nan, monotone_constraints=None,
#                                      multi_strategy=None, n_estimators=None,
#                                      n_jobs=None, num_parallel_tree=None,
#                                      random_state=None, ...),
#              n_jobs=-1,
#              param_grid={'colsample_bytree': [0.8, 0.9, 1.0],
#                          'learning_rate': [0.01, 0.05, 0.1],
#                          'max_depth': [3, 4, 5], 'n_estimators': [50, 100, 200],
#                          'subsample': [0.8, 0.9, 1.0]},
#              scoring='roc_auc')

# %%
# Extract the best parameters
best_params = grid_search.best_params_
best_params
# Out:
# {'colsample_bytree': 1.0,
#  'learning_rate': 0.1,
#  'max_depth': 3,
#  'n_estimators': 200,
#  'subsample': 0.8}

# %%
# Train the final model with the best parameters
best_xgb_model = grid_search.best_estimator_
y_pred = best_xgb_model.predict(X_test_encoded)
y_prob = best_xgb_model.predict_proba(X_test_encoded)[:, 1]

# %%
# Evaluate the final model
roc_auc = roc_auc_score(y_test, y_prob)
roc_auc
# Out:
# np.float64(0.988611382406465)

# %%
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98     11423
#            1       0.85      0.75      0.80      1074
#
#     accuracy                           0.97     12497
#    macro avg       0.91      0.87      0.89     12497
# weighted avg       0.97      0.97      0.97     12497

# %% [markdown]
# ### SHAP

# %%
# !pip install shap
# Out:
# Collecting shap
#   Downloading shap-0.48.0-cp39-cp39-macosx_11_0_arm64.whl.metadata (25 kB)
# Requirement already satisfied: numpy in /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages (from shap) (2.0.2)
# Requirement already satisfied: scipy in /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages (from shap) (1.13.1)
# Requirement already satisfied: scikit-learn in /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages (from shap) (1.6.1)
# Requirement already satisfied: pandas in /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages (from shap) (2.3.2)
# Requirement already satisfied: tqdm>=4.27.0 in /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages (from shap) (4.67.1)
# Requirement already satisfied: packaging>20.9 in /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages (from shap) (25.0)
# Collecting slicer==0.0.8 (from shap)
#   Downloading slicer-0.0.8-py3-none-any.whl.metadata (4.0 kB)
# Collecting numba>=0.54 (from shap)
#   Downloading numba-0.60.0-cp39-cp39-macosx_11_0_arm64.whl.metadata (2.7 kB)
# Collecting cloudpickle (from shap)
#   Downloading cloudpickle-3.1.1-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: typing-extensions in /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages (from shap) (4.15.0)
# Collecting llvmlite<0.44,>=0.43.0dev0 (from numba>=0.54->shap)
#   Downloading llvmlite-0.43.0-cp39-cp39-macosx_11_0_arm64.whl.metadata (4.8 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages (from pandas->shap) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages (from pandas->shap) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages (from pandas->shap) (2025.2)
# Requirement already satisfied: six>=1.5 in /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas->shap) (1.17.0)
# Requirement already satisfied: joblib>=1.2.0 in /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages (from scikit-learn->shap) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/nandinimenon/Desktop/Personal-Projects/Personal-Projects/venv/lib/python3.9/site-packages (from scikit-learn->shap) (3.6.0)
# Downloading shap-0.48.0-cp39-cp39-macosx_11_0_arm64.whl (548 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 548.7/548.7 kB 1.1 MB/s  0:00:00m eta 0:00:01
# Downloading slicer-0.0.8-py3-none-any.whl (15 kB)
# Downloading numba-0.60.0-cp39-cp39-macosx_11_0_arm64.whl (2.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 14.2 MB/s  0:00:00
# Downloading llvmlite-0.43.0-cp39-cp39-macosx_11_0_arm64.whl (28.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 28.8/28.8 MB 14.7 MB/s  0:00:01 eta 0:00:01
# Downloading cloudpickle-3.1.1-py3-none-any.whl (20 kB)
# Installing collected packages: slicer, llvmlite, cloudpickle, numba, shap
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5/5 [shap]4/5 [shap]]te]
# Successfully installed cloudpickle-3.1.1 llvmlite-0.43.0 numba-0.60.0 shap-0.48.0 slicer-0.0.8

# %%
import shap

# Create a SHAP explainer
explainer = shap.TreeExplainer(best_xgb_model)
shap_values = explainer.shap_values(X_test_encoded)

# %%
# Summary plot
shap.summary_plot(shap_values, X_test_encoded)

# %% [markdown]
# 1. credit_utilization_ratio: High values (red) increase the likelihood of default, as shown by positive SHAP values.
# 2. delinquency_ratio: Similarly, higher values increase the risk, shown by positive SHAP values.
# 3. loan_to_income: Higher values (red) also increase the default risk.
# 4. residence_type_Owned and residence_type_Rented: Different impacts based on whether the residence is owned or rented.
# 5. avg_dpd_per_delinquency: Higher average days past due per delinquency increase the risk.

# %%
# Dependence plot for a specific feature
shap.dependence_plot("credit_utilization_ratio", shap_values, X_test_encoded)

# %%
# plot for a single prediction
shap.initjs()
shap.force_plot(explainer.expected_value, shap_values[0,:], X_test_encoded.iloc[0,:])
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e,t,n={221:(e,t,n)=>{"use strict";var r=n(540);function a(e){var t="https://react.dev/errors/"+e;if(1<arguments.length){t+="?args[]="+encodeURIComponent(arguments[1]);for(var n=2;n<arguments.length;n++)t+="&args[]="+encodeURIComponent(arguments[n])}return"Minified React error #"+e+"; visit "+t+" for the full message or use the non-minified dev environment for full errors and additional helpful warnings."}function i(){}var o={d:{f:i,r:function(){throw Error(a(522))},D:i,C:i,L:i,m:i,X:i,S:i,M:i},p:0,findDOMNode:null},u=Symbol.for("react.portal"),l=r.__CLIENT_INTERNALS_DO_NOT_USE_OR_WARN_USERS_THEY_CANNOT_UPGRADE;function s(e,t){return"font"===e?"":"string"==typeof t?"use-credentials"===t?t:"":void 0}t.__DOM_INTERNALS_DO_NOT_USE_OR_WARN_USERS_THEY_CANNOT_UPGRADE=o,t.createPortal=function(e,t){var n=2<arguments.length&&void 0!==arguments[2]?arguments[2]:null;if(!t||1!==t.nodeType&&9!==t.nodeType&&11!==t.nodeType)throw Error(a(299));return function(e,t,n){var r=3<arguments.length&&void 0!==arguments[3]?arguments[3]:null;return{$$typeof:u,key:null==r?null:""+r,children:e,containerInfo:t,implementation:n}}(e,t,null,n)},t.flushSync=function(e){var t=l.T,n=o.p;try{if(l.T=null,o.p=2,e)return e()}finally{l.T=t,o.p=n,o.d.f()}},t.preconnect=function(e,t){"string"==typeof e&&(t=t?"string"==typeof(t=t.crossOrigin)?"use-credentials"===t?t:"":void 0:null,o.d.C(e,t))},t.prefetchDNS=function(e){"string"==typeof e&&o.d.D(e)},t.preinit=function(e,t){if("string"==typeof e&&t&&"string"==typeof t.as){var n=t.as,r=s(n,t.crossOrigin),a="string"==typeof t.integrity?t.integrity:void 0,i="string"==typeof t.fetchPriority?t.fetchPriority:void 0;"style"===n?o.d.S(e,"string"==typeof t.precedence?t.precedence:void 0,{crossOrigin:r,integrity:a,fetchPriority:i}):"script"===n&&o.d.X(e,{crossOrigin:r,integrity:a,fetchPriority:i,nonce:"string"==typeof t.nonce?t.nonce:void 0})}},t.preinitModule=function(e,t){if("string"==typeof e)if("object"==typeof t&&null!==t){if(null==t.as||"script"===t.as){var n=s(t.as,t.crossOrigin);o.d.M(e,{crossOrigin:n,integrity:"string"==typeof t.integrity?t.integrity:void 0,nonce:"string"==typeof t.nonce?t.nonce:void 0})}}else null==t&&o.d.M(e)},t.preload=function(e,t){if("string"==typeof e&&"object"==typeof t&&null!==t&&"string"==typeof t.as){var n=t.as,r=s(n,t.crossOrigin);o.d.L(e,n,{crossOrigin:r,integrity:"string"==typeof t.integrity?t.integrity:void 0,nonce:"string"==typeof t.nonce?t.nonce:void 0,type:"string"==typeof t.type?t.type:void 0,fetchPriority:"string"==typeof t.fetchPriority?t.fetchPriority:void 0,referrerPolicy:"string"==typeof t.referrerPolicy?t.referrerPolicy:void 0,imageSrcSet:"string"==typeof t.imageSrcSet?t.imageSrcSet:void 0,imageSizes:"string"==typeof t.imageSizes?t.imageSizes:void 0,media:"string"==typeof t.media?t.media:void 0})}},t.preloadModule=function(e,t){if("string"==typeof e)if(t){var n=s(t.as,t.crossOrigin);o.d.m(e,{as:"string"==typeof t.as&&"script"!==t.as?t.as:void 0,crossOrigin:n,integrity:"string"==typeof t.integrity?t.integrity:void 0})}else o.d.m(e)},t.requestFormReset=function(e){o.d.r(e)},t.unstable_batchedUpdates=function(e,t){return e(t)},t.useFormState=function(e,t,n){return l.H.useFormState(e,t,n)},t.useFormStatus=function(){return l.H.useHostTransitionStatus()},t.version="19.1.0"},247:(e,t,n)=>{"use strict";var r=n(982),a=n(540),i=n(961);function o(e){var t="https://react.dev/errors/"+e;if(1<arguments.length){t+="?args[]="+encodeURIComponent(arguments[1]);for(var n=2;n<arguments.length;n++)t+="&args[]="+encodeURIComponent(arguments[n])}return"Minified React error #"+e+"; visit "+t+" for the full message or use the non-minified dev environment for full errors and additional helpful warnings."}function u(e){return!(!e||1!==e.nodeType&&9!==e.nodeType&&11!==e.nodeType)}function l(e){var t=e,n=e;if(e.alternate)for(;t.return;)t=t.return;else{e=t;do{!!(4098&(t=e).flags)&&(n=t.return),e=t.return}while(e)}return 3===t.tag?n:null}function s(e){if(13===e.tag){var t=e.memoizedState;if(null===t&&n ...
# <div id='iNMACXALBLJ05NQ9QQWID'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": -2.577409267425537, "outValue": -0.6920615434646606, "link": "identity", "featureNames": ["age", "loan_tenure_months", "number_of_open_accounts", "credit_utilization_ratio", "loan_to_income", "delinquency_ratio", "avg_dpd_per_delinquency", "credit_utilization_per_income", "residence_type_Owned", "residence_type_Rented", "loan_purpose_Education", "loan_purpose_Home", "loan_purpose_Personal", "loan_type_Unsecured"], "features": {"0": {"effect": 0.07443725317716599, "value": 0.34615384615384615}, "1": {"effect": 0.12159722298383713, "value": 0.7547169811320754}, "2": {"effect": -0.10318587720394135, "value": 0.3333333333333333}, "3": {"effect": 4.543215274810791, "value": 0.98989898989899}, "4": {"effect": 0.6653349995613098, "value": 0.550351288056206}, "5": {"effect": -1.4839531183242798, "value": 0.0}, "6": {"effect": -0.6147950291633606, "value": 0.0}, "7": {"effect": 0.014839145354926586, "value": 0.12706043956043955}, "8": {"effect": -0.7124284505844116, "value": 1.0}, "9": {"effect": -0.3837416172027588, "value": 0.0}, "10": {"effect": -0.12522758543491364, "value": 0.0}, "12": {"effect": -0.11074473708868027, "value": 0.0}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iNMACXALBLJ05NQ9QQWID')
#   );
# </script>
